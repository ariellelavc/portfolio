# %% [markdown]
# ## CRISPR screen analysis
#
# The __Clustered Regularly Interspaced Short Palindromic Repeats (CRISPR) system__ is a bacterial immune system that has been modified for genome engineering. CRISPR consists of two components: a guide RNA (gRNA) and a non-specific CRISPR-associated endonuclease (Cas9). The gRNA is a short synthetic RNA composed of a scaffold sequence necessary for Cas9-binding (trRNA) and ~20 nucleotide spacer or targeting sequence which defines the genomic target to be modified (crRNA). sgRNA (single guide RNA) is a single RNA molecule that contains both the custom-designed short crRNA sequence fused to the scaffold tracrRNA sequence. Cas9 induces double-stranded breaks (DSB) within the target DNA. The resulting DSB is then repaired by either error-prone Non-Homologous End Joining (NHEJ) pathway or less efficient but high-fidelity Homology Directed Repair (HDR) pathway. The NHEJ pathway is the most active repair mechanism and it leads to small nucleotide insertions or deletions (indels) at the DSB site. This results in in-frame amino acid deletions, insertions or frameshift mutations leading to premature stop codons within the open reading frame (ORF) of the targeted gene. The end result is a loss-of-function mutation within the targeted gene.
#
# The ease of generating gRNAs makes CRISPR one of the most scalable genome editing technologies. Genome-wide screens enable systematic targeting of thousands of genes, with one gene targeted per cell, to identify genes driving phenotypes, such as cell survival, drug resistance or sensitivity.
#
# Below, a __CRISPR perturbation screen analysis to identify genes whose knockout increases cancer cells sensitivity to a drug__.
#
# CRISPR screen data is analysed using MAGeCK and standard read quality tools. CRISPR screen reads are assessed for quality using __fastp__ sequencing tool. The detection of enriched guides can be performed using MAGeCK. Downstream analysis include visualisations, such as volcano plot, and pathway analysis with tools like fgsea.

# %% [markdown]
# ### Data
#
# 3 samples from human esophageal cancer cell line (OACM5.1): a baseline sample taken at time zero (T0-Control), a sample treated with drug for 8 days (T8-APR-246) and a control sample treated with vehicle for 8 days (T8-Vehicle) [10.1101/2020.11.29.398867](10.1101/2020.11.29.398867).
#
# APR-246 is a mutant-p53 targeted therapeutic (targeting antioxidant pathways) under clinical investigation in acute myeloid leukemia (AML).

# %% [markdown]
# ### Processing reads
#
# #### QC and adapter trimming
#
# Use __fastp__ - fast all-in-one preprocessing tool for fastq files which performs quality control, adapter trimming, quality filtering, per-read quality pruning, and provides the filtering results in various formats (HTML, JSON).

# %%
import numpy as np
import pandas as pd

# %%
samples = ['T0-Control', 'T8-APR-246', 'T8-Vehicle']

adapters = pd.read_csv("adapter_list.tsv", delimiter='\t')
adapters
# Out:
#       Illumina Universal Adapter  AGATCGGAAGAG
# 0  Illumina Small RNA 3' Adapter  TGGAATTCTCGG
# 1  Illumina Small RNA 5' Adapter  GATCGTCGGACT
# 2   Nextera Transposase Sequence  CTGTCTCTTATA
# 3  CRISPR lentiGuide Puro 5prime  TGTGGAAAGGAC
# 4  CRISPR lentiGuide Puro 3prime  GTTTTAGAGCTA

# %% [markdown]
# The 5' adapter sequence, TGTGGAAAGGAC, from the Brunello library vector used with this dataset (lentiGuide-Puro) will be trimmed.

# %%
for sample in samples:
    ! fastp -i {sample}.fastq.gz -o qc/{sample}.fastq.gz --adapter_sequence=TGTGGAAAGGAC -w 4 -h qc/{sample}.html -j qc/{sample}.json
# Out:
# Read1 before filtering:
# total reads: 213111
# total bases: 15983325
# Q20 bases: 14506936(90.7629%)
# Q30 bases: 13902387(86.9806%)
#
# Read1 after filtering:
# total reads: 1488
# total bases: 111505
# Q20 bases: 94780(85.0007%)
# Q30 bases: 89011(79.8269%)
#
# Filtering result:
# reads passed filter: 1488
# reads failed due to low quality: 6858
# reads failed due to too many N: 0
# reads failed due to too short: 204765
# reads with adapter trimmed: 211347
# bases trimmed due to adapters: 14849002
#
# Duplication rate (may be overestimated since this is SE data): 8.47774%
#
# JSON report: qc/T0-Control.json
# HTML report: qc/T0-Control.html
#
# fastp -i T0-Control.fastq.gz -o qc/T0-Control.fastq.gz --adapter_sequence=TGTGGAAAGGAC -w 4 -h qc/T0-Control.html -j qc/T0-Control.json
# fastp v0.23.2, time used: 2 seconds
# Read1 before filtering:
# total reads: 187963
# total bases: 14097225
# Q20 bases: 12812053(90.8835%)
# Q30 bases: 12284537(87.1415%)
#
# Read1 after filtering:
# total reads: 1202
# total bases: 90092
# Q20 bases: 77306(85.8078%)
# Q30 bases: 72890(80.9062%)
#
# Filtering result:
# reads passed filter: 1202
# reads failed due to low quality: 5864
# reads failed due to too many N: 0
# reads failed due to too short: 180897
# reads with adapter trimmed: 186534
# bases trimmed due to adapters: 13104835
#
# Duplication rate (may be overestimated since this is SE data): 8.76555%
#
# JSON report: qc/T8-APR-246.json
# HTML report: qc/T8-APR-246.html
#
# fastp -i T8-APR-246.fastq.gz -o qc/T8-APR-246.fastq.gz --adapter_sequence=TGTGGAAAGGAC -w 4 -h qc/T8-APR-246.html -j qc/T8-APR-246.json
# fastp v0.23.2, time used: 1 seconds
# Read1 before filtering:
# total reads: 184346
# total bases: 13825950
# Q20 bases: 12557012(90.8221%)
# Q30 bases: 12036916(87.0603%)
#
# Read1 after filtering:
# total reads: 1221
# total bases: 91308
# Q20 bases: 77593(84.9794%)
# Q30 bases: 72988(79.936%)
#
# Filtering result:
# reads passed filter: 1221
# reads failed due to low quality: 5896
# reads failed due to too many N: 0
# reads failed due to too short: 177229
# reads with adapter trimmed: 182823
# bases trimmed due to adapters: 12843341
#
# Duplication rate (may be overestimated since this is SE data): 8.6853%
#
# JSON report: qc/T8-Vehicle.json
# HTML report: qc/T8-Vehicle.html
#
# fastp -i T8-Vehicle.fastq.gz -o qc/T8-Vehicle.fastq.gz --adapter_sequence=TGTGGAAAGGAC -w 4 -h qc/T8-Vehicle.html -j qc/T8-Vehicle.json
# fastp v0.23.2, time used: 1 seconds

# %% [markdown]
# #### Counting
#
# Use __[MAGeCK](10.1186/s13059-014-0554-4)__ (Model-based Analysis of Genome-wide CRISPR/Cas9 Knockout) method for prioritizing single-guide RNAs, genes and pathways in genome-scale CRISPR/Cas9 knockout screens. MAGeCK identifies both positively and negatively selected genes simultaneously, and reports robust results across different experimental conditions.
#
# To count the number of guides for each gene, [__MAGeCK__](https://sourceforge.net/p/mageck/wiki/usage/) __`count`__ needs a library file containing list of sgRNA names, the sequences and target genes, specifying which guide sequence belongs to which gene. The guides here are from the [Brunello](10.1038/nbt.3437) library which contains 77,441 sgRNAs, an average of 4 sgRNAs per gene, and 1000 non-targeting control sgRNAs.

# %%
sgRNA_library = pd.read_csv("counting/sgRNA_library.tsv", delimiter="\t", header=None)
sgRNA_library.head(10)
# Out:
#        0                     1     2
# 0   ID_1  CATCTTCTTTCACCTGAACG  A1BG
# 1   ID_2  CTCCGGGGAGAACTCCGGCG  A1BG
# 2   ID_3  TCTCCATGGTGCATCAGCAC  A1BG
# 3   ID_4  TGGAAGTCCACTCCACTCAG  A1BG
# 4   ID_5  ACTGCATCTGTGCAAACGGG   A2M
# 5   ID_6  ATGTCTCATGAACTACCCTG   A2M
# 6   ID_7  TGAAATGAAACTTCACACTG   A2M
# 7   ID_8  TTACTCATATAGGATCCCAA   A2M
# 8   ID_9  CGGAAGACACAAGGCACCTG  NAT1
# 9  ID_10  GAACCTTAACATCCATTGTG  NAT1

# %%
! mageck count -l "counting/sgRNA_library.tsv" \
--fastq "qc/T0-Control.fastq.gz" "qc/T8-APR-246.fastq.gz" "qc/T8-Vehicle.fastq.gz" \
--sample-label "T0-Control","T8-APR-246","T8-Vehicle" -n output --pdf-report --keep-tmp   --norm-method median
# Out:
# INFO  @ Thu, 21 Dec 2023 07:39:30: Parameters: /usr/local/bin/mageck count -l counting/sgRNA_library.tsv --fastq qc/T0-Control.fastq.gz qc/T8-APR-246.fastq.gz qc/T8-Vehicle.fastq.gz --sample-label T0-Control,T8-APR-246,T8-Vehicle -n output --pdf-report --keep-tmp --norm-method median
# INFO  @ Thu, 21 Dec 2023 07:39:30: Welcome to MAGeCK v0.5.9.5. Command: count
# INFO  @ Thu, 21 Dec 2023 07:39:30: Loading 77441 predefined sgRNAs.
# WARNING @ Thu, 21 Dec 2023 07:39:30: There are 0 sgRNAs with duplicated sequences.
# INFO  @ Thu, 21 Dec 2023 07:39:30: Parsing FASTQ file qc/T0-Control.fastq.gz...
# INFO  @ Thu, 21 Dec 2023 07:39:30: Determining the trim-5 length of FASTQ file qc/T0-Control.fastq.gz...
# INFO  @ Thu, 21 Dec 2023 07:39:30: Possible gRNA lengths:20
# INFO  @ Thu, 21 Dec 2023 07:39:30: Processing 0M reads ...
# INFO  @ Thu, 21 Dec 2023 07:39:30: Read length:75,63,40,61,54,62
# INFO  @ Thu, 21 Dec 2023 07:39:30: Total tested reads: 1488, mapped: 1016(0.6827956989247311)
# INFO  @ Thu, 21 Dec 2023 07:39:30: --trim-5 test data: (trim_length reads fraction)
# INFO  @ Thu, 21 Dec 2023 07:39:30: 23	150	0.14763779527559054
# INFO  @ Thu, 21 Dec 2023 07:39:30: 25	138	0.13582677165354332
# INFO  @ Thu, 21 Dec 2023 07:39:30: 24	129	0.12696850393700787
# INFO  @ Thu, 21 Dec 2023 07:39:30: 22	115	0.11318897637795275
# INFO  @ Thu, 21 Dec 2023 07:39:30: 27	97	0.09547244094488189
# INFO  @ Thu, 21 Dec 2023 07:39:30: 29	91	0.08956692913385826
# INFO  @ Thu, 21 Dec 2023 07:39:30: 28	89	0.08759842519685039
# INFO  @ Thu, 21 Dec 2023 07:39:30: 21	75	0.07381889763779527
# INFO  @ Thu, 21 Dec 2023 07:39:30: 26	51	0.05019685039370079
# INFO  @ Thu, 21 Dec 2023 07:39:30: 30	35	0.0344488188976378
# INFO  @ Thu, 21 Dec 2023 07:39:30: 31	16	0.015748031496062992
# INFO  @ Thu, 21 Dec 2023 07:39:30: 20	16	0.015748031496062992
# INFO  @ Thu, 21 Dec 2023 07:39:30: 18	6	0.005905511811023622
# INFO  @ Thu, 21 Dec 2023 07:39:30: 19	3	0.002952755905511811
# INFO  @ Thu, 21 Dec 2023 07:39:30: 16	2	0.001968503937007874
# INFO  @ Thu, 21 Dec 2023 07:39:30: 17	2	0.001968503937007874
# INFO  @ Thu, 21 Dec 2023 07:39:30: 14	1	0.000984251968503937
# INFO  @ Thu, 21 Dec 2023 07:39:30: Auto determination of trim5 results: 23,25,24,22,27,29,28
# INFO  @ Thu, 21 Dec 2023 07:39:30: Possible gRNA lengths:20
# INFO  @ Thu, 21 Dec 2023 07:39:30: Processing 0M reads ..
# INFO  @ Thu, 21 Dec 2023 07:39:30: Total: 1488.
# INFO  @ Thu, 21 Dec 2023 07:39:30: Mapped: 809.
# INFO  @ Thu, 21 Dec 2023 07:39:30: Parsing FASTQ file qc/T8-APR-246.fastq.gz...
# INFO  @ Thu, 21 Dec 2023 07:39:30: Determining the trim-5 length of FASTQ file qc/T8-APR-246.fastq.gz...
# INFO  @ Thu, 21 Dec 2023 07:39:30: Possible gRNA lengths:20
# INFO  @ Thu, 21 Dec 2023 07:39:30: Processing 0M reads ...
# INFO  @ Thu, 21 Dec 2023 07:39:30: Read length:75,28,64
# INFO  @ Thu, 21 Dec 2023 07:39:30: Total tested reads: 1202, mapped: 799(0.6647254575707154)
# INFO  @ Thu, 21 Dec 2023 07:39:30: --trim-5 test data: (trim_length reads fraction)
# INFO  @ Thu, 21 Dec 2023 07:39:30: 23	103	0.12891113892365458
# INFO  @ Thu, 21 Dec 2023 07:39:30: 24	100	0.1251564455569462
# INFO  @ Thu, 21 Dec 2023 07:39:30: 27	98	0.12265331664580725
# INFO  @ Thu, 21 Dec 2023 07:39:30: 25	97	0.1214017521902378
# INFO  @ Thu, 21 Dec 2023 07:39:30: 22	88	0.11013767209011265
# INFO  @ Thu, 21 Dec 2023 07:39:30: 28	83	0.10387984981226533
# INFO  @ Thu, 21 Dec 2023 07:39:30: 29	79	0.09887359198998748
# INFO  @ Thu, 21 Dec 2023 07:39:30: 21	76	0.0951188986232791
# INFO  @ Thu, 21 Dec 2023 07:39:30: 26	32	0.04005006257822278
# INFO  @ Thu, 21 Dec 2023 07:39:30: 30	13	0.016270337922403004
# INFO  @ Thu, 21 Dec 2023 07:39:30: 18	7	0.008760951188986232
# INFO  @ Thu, 21 Dec 2023 07:39:30: 20	7	0.008760951188986232
# INFO  @ Thu, 21 Dec 2023 07:39:30: 31	7	0.008760951188986232
# INFO  @ Thu, 21 Dec 2023 07:39:30: 19	5	0.006257822277847309
# INFO  @ Thu, 21 Dec 2023 07:39:30: 17	3	0.0037546933667083854
# INFO  @ Thu, 21 Dec 2023 07:39:30: 14	1	0.0012515644555694619
# INFO  @ Thu, 21 Dec 2023 07:39:30: Auto determination of trim5 results: 23,24,27,25,22,28,29
# INFO  @ Thu, 21 Dec 2023 07:39:30: Possible gRNA lengths:20
# INFO  @ Thu, 21 Dec 2023 07:39:30: Processing 0M reads ..
# INFO  @ Thu, 21 Dec 2023 07:39:30: Total: 1202.
# INFO  @ Thu, 21 Dec 2023 07:39:30: Mapped: 648.
# INFO  @ Thu, 21 Dec 2023 07:39:30: Parsing FASTQ file qc/T8-Vehicle.fastq.gz...
# INFO  @ Thu, 21 Dec 2023 07:39:30: Determining the trim-5 length of FASTQ file qc/T8-Vehicle.fastq.gz...
# INFO  @ Thu, 21 Dec 2023 07:39:30: Possible gRNA lengths:20
# INFO  @ Thu, 21 Dec 2023 07:39:30: Processing 0M reads ...
# INFO  @ Thu, 21 Dec 2023 07:39:30: Read length:75,58,20,63,37,56,30,61
# INFO  @ Thu, 21 Dec 2023 07:39:30: Total tested reads: 1221, mapped: 799(0.6543816543816544)
# INFO  @ Thu, 21 Dec 2023 07:39:30: --trim-5 test data: (trim_length reads fraction)
# INFO  @ Thu, 21 Dec 2023 07:39:30: 24	104	0.13016270337922403
# INFO  @ Thu, 21 Dec 2023 07:39:30: 25	96	0.12015018773466833
# INFO  @ Thu, 21 Dec 2023 07:39:30: 27	92	0.11514392991239049
# INFO  @ Thu, 21 Dec 2023 07:39:30: 29	91	0.11389236545682102
# INFO  @ Thu, 21 Dec 2023 07:39:30: 22	90	0.11264080100125157
# INFO  @ Thu, 21 Dec 2023 07:39:30: 28	86	0.10763454317897372
# INFO  @ Thu, 21 Dec 2023 07:39:30: 23	85	0.10638297872340426
# INFO  @ Thu, 21 Dec 2023 07:39:30: 21	83	0.10387984981226533
# INFO  @ Thu, 21 Dec 2023 07:39:30: 26	35	0.04380475594493116
# INFO  @ Thu, 21 Dec 2023 07:39:30: 30	16	0.02002503128911139
# INFO  @ Thu, 21 Dec 2023 07:39:30: 20	7	0.008760951188986232
# INFO  @ Thu, 21 Dec 2023 07:39:30: 31	5	0.006257822277847309
# INFO  @ Thu, 21 Dec 2023 07:39:30: 14	4	0.0050062578222778474
# INFO  @ Thu, 21 Dec 2023 07:39:30: 17	2	0.0025031289111389237
# INFO  @ Thu, 21 Dec 2023 07:39:30: 19	2	0.0025031289111389237
# INFO  @ Thu, 21 Dec 2023 07:39:30: 18	1	0.0012515644555694619
# INFO  @ Thu, 21 Dec 2023 07:39:30: Auto determination of trim5 results: 24,25,27,29,22,28,23
# INFO  @ Thu, 21 Dec 2023 07:39:30: Possible gRNA lengths:20
# INFO  @ Thu, 21 Dec 2023 07:39:30: Processing 0M reads ..
# INFO  @ Thu, 21 Dec 2023 07:39:30: Total: 1221.
# INFO  @ Thu, 21 Dec 2023 07:39:30: Mapped: 644.
# WARNING @ Thu, 21 Dec 2023 07:39:30: Sample 0 has zero median count, so median normalization is not possible. Switch to total read count normalization.
# WARNING @ Thu, 21 Dec 2023 07:39:30: Sample 0 has too many zero-count sgRNAs (0.6113813229571985), and median normalization is unstable. Switch to total read count normalization.
# WARNING @ Thu, 21 Dec 2023 07:39:30: Sample 1 has zero median count, so median normalization is not possible. Switch to total read count normalization.
# WARNING @ Thu, 21 Dec 2023 07:39:30: Sample 1 has too many zero-count sgRNAs (0.6857976653696498), and median normalization is unstable. Switch to total read count normalization.
# WARNING @ Thu, 21 Dec 2023 07:39:30: Sample 2 has zero median count, so median normalization is not possible. Switch to total read count normalization.
# WARNING @ Thu, 21 Dec 2023 07:39:30: Sample 2 has too many zero-count sgRNAs (0.6896887159533074), and median normalization is unstable. Switch to total read count normalization.
# INFO  @ Thu, 21 Dec 2023 07:39:30: Final size factor: 0.865677791512155 1.080761316872428 1.0874741200828157
# INFO  @ Thu, 21 Dec 2023 07:39:30: Summary of file qc/T0-Control.fastq.gz:
# INFO  @ Thu, 21 Dec 2023 07:39:30: label	T0-Control
# INFO  @ Thu, 21 Dec 2023 07:39:30: reads	1488
# INFO  @ Thu, 21 Dec 2023 07:39:30: mappedreads	809
# INFO  @ Thu, 21 Dec 2023 07:39:30: totalsgrnas	77441
# INFO  @ Thu, 21 Dec 2023 07:39:30: zerosgrnas	76642
# INFO  @ Thu, 21 Dec 2023 07:39:30: giniindex	0.9897692979128031
# INFO  @ Thu, 21 Dec 2023 07:39:30: Summary of file qc/T8-APR-246.fastq.gz:
# INFO  @ Thu, 21 Dec 2023 07:39:30: label	T8-APR-246
# INFO  @ Thu, 21 Dec 2023 07:39:30: reads	1202
# INFO  @ Thu, 21 Dec 2023 07:39:30: mappedreads	648
# INFO  @ Thu, 21 Dec 2023 07:39:30: totalsgrnas	77441
# INFO  @ Thu, 21 Dec 2023 07:39:30: zerosgrnas	76795
# INFO  @ Thu, 21 Dec 2023 07:39:30: giniindex	0.9916860045784042
# INFO  @ Thu, 21 Dec 2023 07:39:30: Summary of file qc/T8-Vehicle.fastq.gz:
# INFO  @ Thu, 21 Dec 2023 07:39:30: label	T8-Vehicle
# INFO  @ Thu, 21 Dec 2023 07:39:30: reads	1221
# INFO  @ Thu, 21 Dec 2023 07:39:30: mappedreads	644
# INFO  @ Thu, 21 Dec 2023 07:39:30: totalsgrnas	77441
# INFO  @ Thu, 21 Dec 2023 07:39:30: zerosgrnas	76803
# INFO  @ Thu, 21 Dec 2023 07:39:30: giniindex	0.991818927504039
# INFO  @ Thu, 21 Dec 2023 07:39:30: Loading Rnw template file: /usr/local/lib/python3.8/site-packages/mageck/count_report.Rmd.
# INFO  @ Thu, 21 Dec 2023 07:39:30: Loading Rnw template file: /usr/local/lib/python3.8/site-packages/mageck/fastq_template.Rnw.
# INFO  @ Thu, 21 Dec 2023 07:39:30: Running command: cd ./; Rscript output_countsummary.R
# INFO  @ Thu, 21 Dec 2023 07:39:33: Command message:
# INFO  @ Thu, 21 Dec 2023 07:39:33:   Writing to file output_countsummary.tex
# INFO  @ Thu, 21 Dec 2023 07:39:33:   Processing code chunks with options ...
# INFO  @ Thu, 21 Dec 2023 07:39:33:    1 : keep.source term verbatim (label = funcdef, output_countsummary.Rnw:28)
# INFO  @ Thu, 21 Dec 2023 07:39:33:    2 : keep.source term tex (label = tab1, output_countsummary.Rnw:174)
# INFO  @ Thu, 21 Dec 2023 07:39:33:    3 : keep.source term tex (label = tab2, output_countsummary.Rnw:192)
# INFO  @ Thu, 21 Dec 2023 07:39:33:    4 : keep.source term tex (label = tab3, output_countsummary.Rnw:206)
# INFO  @ Thu, 21 Dec 2023 07:39:33:    5 : keep.source term verbatim pdf  (output_countsummary.Rnw:239)
# INFO  @ Thu, 21 Dec 2023 07:39:33:    6 : keep.source term verbatim pdf  (output_countsummary.Rnw:246)
# INFO  @ Thu, 21 Dec 2023 07:39:33:    7 : keep.source term verbatim pdf  (output_countsummary.Rnw:256)
# INFO  @ Thu, 21 Dec 2023 07:39:33:    8 : keep.source term verbatim pdf  (output_countsummary.Rnw:260)
# INFO  @ Thu, 21 Dec 2023 07:39:33:    9 : keep.source term verbatim pdf  (output_countsummary.Rnw:269)
# INFO  @ Thu, 21 Dec 2023 07:39:33:
# INFO  @ Thu, 21 Dec 2023 07:39:33:   You can now run (pdf)latex on ‘output_countsummary.tex’
# INFO  @ Thu, 21 Dec 2023 07:39:33:   Error in texi2dvi("output_countsummary.tex", pdf = TRUE) :
# INFO  @ Thu, 21 Dec 2023 07:39:33:     pdflatex is not available
# INFO  @ Thu, 21 Dec 2023 07:39:33:   In addition: Warning message:
# INFO  @ Thu, 21 Dec 2023 07:39:33:   In texi2dvi("output_countsummary.tex", pdf = TRUE) :
# INFO  @ Thu, 21 Dec 2023 07:39:33:     texi2dvi script/program not available, using emulation
# INFO  @ Thu, 21 Dec 2023 07:39:33:   Execution halted
# INFO  @ Thu, 21 Dec 2023 07:39:33:
# INFO  @ Thu, 21 Dec 2023 07:39:33: End command message.

# %%
# ! gs -dBATCH -dNOPAUSE -q -dPDFSETTINGS=/prepress -sDEVICE=pdfwrite -sOutputFile=merged.pdf *.pdf

# %% [markdown]
# Inspect the MAGeCK count files (sgRNA counts, counts summary and plots pdf) previously generated for the full dataset (as mageck count above was performed on 1% of the full dataset).

# %% [markdown]
# __sgRNA counts__

# %%
sgRNA_counts = pd.read_csv("counting/full_mageck_sgrna_counts.tsv", delimiter="\t")
sgRNA_counts.head(10)
# Out:
#       sgRNA             Gene  T8-APR-246  T8-Vehicle  T0-Control
# 0  ID_30030           DUSP14         172         195         205
# 1  ID_21657        HIST1H2BL          84          55          85
# 2  ID_69143           CTAGE6         118         232         257
# 3  ID_70279         TBC1D10C         272         232         308
# 4  ID_21824          PIP5K1B         352         388         395
# 5  ID_77019  controlguide578         445         365         293
# 6  ID_49661          GALNT12         243         213         224
# 7  ID_23709             MAP7         273         181         242
# 8  ID_27699            APBB3          96         114         159
# 9  ID_41971             EXD2         172         121         152

# %% [markdown]
# __Counts summary__
#
# Counts summary file summarizes QC measurements of the fastq files, and evaluates the degree of negative selection in known essential genes - only if option --day0-label is provided, MAGeck will run pathway analysis for each sample, and use GSEA metrics (columns 9-13 in table below) to evaluate the quality of the samples.

# %%
counts_summary = pd.read_csv("counting/full_mageck_count_summary.tsv", delimiter="\t")
counts_summary
# Out:
#                File       Label     Reads    Mapped  Percentage  TotalsgRNAs  \
# 0  T8-APR-246.fq.gz  T8-APR-246  18165059  14665554      0.8073        77441
# 1  T8-Vehicle.fq.gz  T8-Vehicle  17855968  15019692      0.8412        77441
# 2  T0-Control.fq.gz  T0-Control  20646404  17272052      0.8366        77441
#
#    Zerocounts  GiniIndex  NegSelQC  NegSelQCPval  NegSelQCPvalPermutation  \
# 0        2102    0.13620         0             1                        1
# 1        1659    0.12750         0             1                        1
# 2         535    0.09077         0             1                        1
#
#    NegSelQCPvalPermutationFDR  NegSelQCGene
# 0                           1           0.0
# 1                           1           0.0
# 2                           1           0.0

# %%
counts_summary.columns
# Out:
# Index(['File', 'Label', 'Reads', 'Mapped', 'Percentage', 'TotalsgRNAs',
#        'Zerocounts', 'GiniIndex', 'NegSelQC', 'NegSelQCPval',
#        'NegSelQCPvalPermutation', 'NegSelQCPvalPermutationFDR',
#        'NegSelQCGene'],
#       dtype='object')

# %%
counts_summary_info= {'Column_name': counts_summary.columns, 
                     'Content': ['The fastq file used', 
                                 'The label of that fastq file assigned', 
                                 'Total number reads in the fastq file (Recommended: 100-300 times the number of sgRNAs)', 
                                 'Total number of reads that can be mapped to library',
                                 'Mapped percentage, calculated as Mapped/Reads (Recommended: at least 60%)', 
                                 'Total number of sgRNAs in the library',
                                 'Total number of missing sgRNAs (Recommended: no more than 1%)',
                                 'The Gini Index of the read count distribution. A smaller value indicates more eveness of the count distribution (Recommended: around 0.1 for plasmid or initial state samples, and around 0.2-0.3 for negative selection samples)',
                                 'The enrichment score (ES) of GSEA',
                                 'The p-value of the GSEA analysis (Recommended: smaller than 1e-10)',
                                 'The permutation p-value',
                                 'The FDR of the permutation p-value',
                                 'The number of essential genes found in the library that are evaluated for GSEA analysis'
                                ]}
pd.DataFrame.from_dict(counts_summary_info)
# Out:
#                    Column_name  \
# 0                         File
# 1                        Label
# 2                        Reads
# 3                       Mapped
# 4                   Percentage
# 5                  TotalsgRNAs
# 6                   Zerocounts
# 7                    GiniIndex
# 8                     NegSelQC
# 9                 NegSelQCPval
# 10     NegSelQCPvalPermutation
# 11  NegSelQCPvalPermutationFDR
# 12                NegSelQCGene
#
#                                               Content
# 0                                 The fastq file used
# 1               The label of that fastq file assigned
# 2   Total number reads in the fastq file (Recommen...
# 3   Total number of reads that can be mapped to li...
# 4   Mapped percentage, calculated as Mapped/Reads ...
# 5               Total number of sgRNAs in the library
# 6   Total number of missing sgRNAs (Recommended: n...
# 7   The Gini Index of the read count distribution....
# 8                   The enrichment score (ES) of GSEA
# 9   The p-value of the GSEA analysis (Recommended:...
# 10                            The permutation p-value
# 11                 The FDR of the permutation p-value
# 12  The number of essential genes found in the lib...

# %% [markdown]
# Data quality is good for the 3 samples.
#
# - There are enough sequenced reads: for T0 control sample there are 17,272,052 reads mapped to guides, 77,441 guides so we there are ~220 reads per guide (17,272,052/77,441), for T8-APR 14,665,554 reads mapped to guides/77441 guides ~ 190 reads per guide, and for T8-Vehicle 15019692/77441 ~ 190 reads/guide. A minimum of 100 reads per guide, preferably 300, is recommended. OK
# - The mapped percentage is good:  >80% mapped for all 3 samples (percentage column). recommended at least 60%. OK
# - The sgRNA zero count is good: T0-Control has 0.69% (535/77441 * 100) sgRNAs that have no reads mapped, which is good. The T8 samples are just slightly high at 2.1% (1659/77441 * 100) and 2.7% (2102/77441 * 100). Recommended no more than 1%.
# - The Gini Index is good: Gini index (a measure of inequality) is used in CRISPR analysis to assess if sgRNAs are present in equal amounts. In positive selection experiments, where only some sgRNAs dominate, the index can be high. However, in plasmid library, in early time points, or negative selection experiments, the remaining sgRNAs that haven’t been negatively selected are expected to display a fairly even distribution. A high Gini index in the latter types of sample can indicate CRISPR oligonucleotide synthesis unevenness, low viral transfection efficiency, and overselection, respectively. The Gini Index is 0.09 for T0-Control (initial state) which is good. The T8 samples are higher at 0.12 and 0.13 but good for a negative selection experiment. Recommended: around 0.1 for plasmid or initial state samples, and around 0.2-0.3 for negative selection samples

# %% [markdown]
# __Plots PDF__
#
# [MAGeCK count report](./counting/full_mageck_count_report.pdf)

# %%
from IPython.display import IFrame
IFrame("counting/full_mageck_count_report.pdf", width=600, height=300)
# Out:
#         <iframe
#             width="600"
#             height="300"
#             src="counting/full_mageck_count_report.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# - The __boxplots__ show largely similiar distributions of counts for the 3 samples. The greater length of the box and between whiskers in the T8 samples compared to the control reflect a bit more variability of counts in those samples, more guides with low and high counts in T8 compared to the T0.
# - The __distribution of read counts plot__ shows how many guides there are for each count (the frequency sums to the total number of guides 77,441). Similar to the boxplots, the wider distribution for T8 compared to T0 shows that those samples have more guides with low and high counts. The peak for T0 appears lower because it has more points (bins) in the plot.
# - The __PCA plot__ shows that the samples from the different conditions separate well. The T8 samples are more similar to each other on PC1 axis than to T0. If the dataset would contain more samples, PCA plots could be used to check for clustering of replicates, batch effect or outliers.
# - The __hierarchical clustering plot__ also shows that the T8 samples are more similar to each other than to T0.

# %% [markdown]
# ### Testing
#
# Use __MAGeCK__ __`test`__ to identify essential genes. Essential means positively or negatively selected sgRNAs and genes. CRISPR positive or negative selection screens can be performed.
#
# With a positive selection screen, most cells die after the treatment (selection) and it is of interest to identify genes whose sgRNAs increase and dominate, indicating loss of those genes helps cells survive that treatment. This can help identify genes essential for drug resistance.
#
# With a negative selection screen, most cells survive after the treatment, and it is of interest to identify genes whose sgRNAs decrease (drop out) compared to a control (e.g. vehicle), indicating those genes are needed for the cells to survive with that treatment. This can help identify genes essential for drug sensitivity.
#
# Regardless of the type of screen performed (positive or negative), MAGeCK can identify both positively and negatively selected genes in the screen by the following algorithm:
# - Raw read counts corresponding to single-guided RNAs (sgRNAs) from different experiments are first normalized using median normalization and mean-variance modeling is used to capture the relationship of mean and variance in replicates.
# - The statistical significance of each sgRNA is calculated using the learned mean-variance model.
# - Essential genes (both positively and negatively selected) are then identified by looking for genes whose sgRNAs are ranked consistently higher (by significance) using robust rank aggregation (RRA).
#
# __The dataset is from a negative selection screen and the aim is to identify genes whose knockout increases the cancer cells sensitivity to the drug__.

# %% [markdown]
# #### Two conditions
#
# __Compare the drug treatment (T8-APR-246) to the vehicle control (T8-Vehicle) using MAGeCK test which employs a robust ranking aggregation (RRA) algorithm__.

# %%
! mageck test -k "counting/full_mageck_sgrna_counts.tsv" -t '0' -c '1' -n output_test --normcounts-to-file \
--pdf-report --norm-method median --adjust-method fdr --sort-criteria neg --remove-zero both --gene-lfc-method median
# Out:
# INFO  @ Thu, 21 Dec 2023 07:40:33: Parameters: /usr/local/bin/mageck test -k counting/full_mageck_sgrna_counts.tsv -t 0 -c 1 -n output_test --normcounts-to-file --pdf-report --norm-method median --adjust-method fdr --sort-criteria neg --remove-zero both --gene-lfc-method median
# INFO  @ Thu, 21 Dec 2023 07:40:33: Welcome to MAGeCK v0.5.9.5. Command: test
# INFO  @ Thu, 21 Dec 2023 07:40:33: Loading count table from counting/full_mageck_sgrna_counts.tsv
# INFO  @ Thu, 21 Dec 2023 07:40:33: Processing 1 lines..
# INFO  @ Thu, 21 Dec 2023 07:40:33: Loaded 77441 records.
# INFO  @ Thu, 21 Dec 2023 07:40:33: Loading Rnw template file: /usr/local/lib/python3.8/site-packages/mageck/test_report.Rmd.
# INFO  @ Thu, 21 Dec 2023 07:40:33: Loading R template file: /usr/local/lib/python3.8/site-packages/mageck/plot_template.RTemplate.
# INFO  @ Thu, 21 Dec 2023 07:40:33: Loading R template file: /usr/local/lib/python3.8/site-packages/mageck/plot_template_indvgene.RTemplate.
# INFO  @ Thu, 21 Dec 2023 07:40:33: Loading Rnw template file: /usr/local/lib/python3.8/site-packages/mageck/plot_template.Rnw.
# INFO  @ Thu, 21 Dec 2023 07:40:33: Treatment samples:0
# INFO  @ Thu, 21 Dec 2023 07:40:33: Treatment sample index:0
# INFO  @ Thu, 21 Dec 2023 07:40:33: Control samples:1
# INFO  @ Thu, 21 Dec 2023 07:40:33: Control sample index:1
# INFO  @ Thu, 21 Dec 2023 07:40:33: Final size factor: 0.9852674473812402 1.0333261386046741
# INFO  @ Thu, 21 Dec 2023 07:40:33: Writing normalized read counts to output_test.normalized.txt
# INFO  @ Thu, 21 Dec 2023 07:40:34: Detecting outliers from variance estimation.. Avg read count:[158.19520942086456], Var: [23877.925254507176]
# INFO  @ Thu, 21 Dec 2023 07:40:34: Skipping 273 sgRNAs from variance calculation because of their extreme high counts (> 4* STD (mean counts) ).
# INFO  @ Thu, 21 Dec 2023 07:40:35: Before RRA, 1318 sgRNAs are removed with zero counts in both group(s).
# INFO  @ Thu, 21 Dec 2023 07:40:35: Use qnorm to reversely calculate sgRNA scores ...
# INFO  @ Thu, 21 Dec 2023 07:40:38: Running command: RRA -i output_test.plow.txt -o output_test.gene.low.txt -p 0.34833099063357986 --skip-gene NA --skip-gene na
# INFO  @ Thu, 21 Dec 2023 07:40:46: Command message:
# INFO  @ Thu, 21 Dec 2023 07:40:46:   Welcome to RRA v 0.5.9.
# INFO  @ Thu, 21 Dec 2023 07:40:46:   Skipping gene NA for permutation ...
# INFO  @ Thu, 21 Dec 2023 07:40:46:   Skipping gene na for permutation ...
# INFO  @ Thu, 21 Dec 2023 07:40:46:   Reading input file...
# INFO  @ Thu, 21 Dec 2023 07:40:46:   Summary: 76123 sgRNAs, 20103 genes, 1 lists; skipped sgRNAs:0
# INFO  @ Thu, 21 Dec 2023 07:40:46:   Computing lo-values for each group...
# INFO  @ Thu, 21 Dec 2023 07:40:46:   Computing false discovery rate...
# INFO  @ Thu, 21 Dec 2023 07:40:46:   Permuting genes with 1 sgRNAs...
# INFO  @ Thu, 21 Dec 2023 07:40:46:   Permuting genes with 2 sgRNAs...
# INFO  @ Thu, 21 Dec 2023 07:40:46:   Permuting genes with 3 sgRNAs...
# INFO  @ Thu, 21 Dec 2023 07:40:46:   Permuting genes with 4 sgRNAs...
# INFO  @ Thu, 21 Dec 2023 07:40:46:   Permuting genes with 7 sgRNAs...
# INFO  @ Thu, 21 Dec 2023 07:40:46:   Permuting genes with 8 sgRNAs...
# INFO  @ Thu, 21 Dec 2023 07:40:46:   Number of genes under FDR adjustment: 20103
# INFO  @ Thu, 21 Dec 2023 07:40:46:   Saving to output file...
# INFO  @ Thu, 21 Dec 2023 07:40:46:   RRA completed.
# INFO  @ Thu, 21 Dec 2023 07:40:46:   Groups deletion complete.
# INFO  @ Thu, 21 Dec 2023 07:40:46:   Lists deletion complete.
# INFO  @ Thu, 21 Dec 2023 07:40:46:
# INFO  @ Thu, 21 Dec 2023 07:40:46: End command message.
# INFO  @ Thu, 21 Dec 2023 07:40:46: Running command: RRA -i output_test.phigh.txt -o output_test.gene.high.txt -p 0.35997004847417996 --skip-gene NA --skip-gene na
# INFO  @ Thu, 21 Dec 2023 07:40:55: Command message:
# INFO  @ Thu, 21 Dec 2023 07:40:55:   Welcome to RRA v 0.5.9.
# INFO  @ Thu, 21 Dec 2023 07:40:55:   Skipping gene NA for permutation ...
# INFO  @ Thu, 21 Dec 2023 07:40:55:   Skipping gene na for permutation ...
# INFO  @ Thu, 21 Dec 2023 07:40:55:   Reading input file...
# INFO  @ Thu, 21 Dec 2023 07:40:55:   Summary: 76123 sgRNAs, 20103 genes, 1 lists; skipped sgRNAs:0
# INFO  @ Thu, 21 Dec 2023 07:40:55:   Computing lo-values for each group...
# INFO  @ Thu, 21 Dec 2023 07:40:55:   Computing false discovery rate...
# INFO  @ Thu, 21 Dec 2023 07:40:55:   Permuting genes with 1 sgRNAs...
# INFO  @ Thu, 21 Dec 2023 07:40:55:   Permuting genes with 2 sgRNAs...
# INFO  @ Thu, 21 Dec 2023 07:40:55:   Permuting genes with 3 sgRNAs...
# INFO  @ Thu, 21 Dec 2023 07:40:55:   Permuting genes with 4 sgRNAs...
# INFO  @ Thu, 21 Dec 2023 07:40:55:   Permuting genes with 7 sgRNAs...
# INFO  @ Thu, 21 Dec 2023 07:40:55:   Permuting genes with 8 sgRNAs...
# INFO  @ Thu, 21 Dec 2023 07:40:55:   Number of genes under FDR adjustment: 20103
# INFO  @ Thu, 21 Dec 2023 07:40:55:   Saving to output file...
# INFO  @ Thu, 21 Dec 2023 07:40:55:   RRA completed.
# INFO  @ Thu, 21 Dec 2023 07:40:55:   Groups deletion complete.
# INFO  @ Thu, 21 Dec 2023 07:40:55:   Lists deletion complete.
# INFO  @ Thu, 21 Dec 2023 07:40:55:
# INFO  @ Thu, 21 Dec 2023 07:40:55: End command message.
# INFO  @ Thu, 21 Dec 2023 07:40:55: Loading top 10 genes from output_test.gene.low.txt: ESD,MTHFD1L,SHMT2,FLI1,TACC3,ACYP1,SYNRG,KIAA1468,ZMYND11,B3GALTL
# INFO  @ Thu, 21 Dec 2023 07:40:56: Loading top 10 genes from output_test.gene.high.txt: ATP5E,ATP5A1,PDE12,NDUFA13,OXSM,NDUFA1,MDH2,NDUFA9,NUBPL,SLC25A19
# INFO  @ Thu, 21 Dec 2023 07:40:56: Running command: rm output_test.plow.txt
# INFO  @ Thu, 21 Dec 2023 07:40:56: Running command: rm output_test.phigh.txt
# INFO  @ Thu, 21 Dec 2023 07:40:56: Running command: rm output_test.gene.low.txt
# INFO  @ Thu, 21 Dec 2023 07:40:56: Running command: rm output_test.gene.high.txt
# INFO  @ Thu, 21 Dec 2023 07:40:56: Running command: cd ./; Rscript output_test.R
# INFO  @ Thu, 21 Dec 2023 07:40:58: Command message:
# INFO  @ Thu, 21 Dec 2023 07:40:58:   null device
# INFO  @ Thu, 21 Dec 2023 07:40:58:             1
# INFO  @ Thu, 21 Dec 2023 07:40:58:   Writing to file output_test_summary.tex
# INFO  @ Thu, 21 Dec 2023 07:40:58:   Processing code chunks with options ...
# INFO  @ Thu, 21 Dec 2023 07:40:58:    1 : keep.source term verbatim (label = funcdef, output_test_summary.Rnw:27)
# INFO  @ Thu, 21 Dec 2023 07:40:58:    2 : keep.source term tex (label = tab1, output_test_summary.Rnw:37)
# INFO  @ Thu, 21 Dec 2023 07:40:58:    3 : keep.source term verbatim (output_test_summary.Rnw:77)
# INFO  @ Thu, 21 Dec 2023 07:40:58:    4 : keep.source term verbatim pdf  (output_test_summary.Rnw:83)
# INFO  @ Thu, 21 Dec 2023 07:40:58:    5 : keep.source term verbatim pdf  (output_test_summary.Rnw:201)
# INFO  @ Thu, 21 Dec 2023 07:40:58:    6 : keep.source term verbatim pdf  (output_test_summary.Rnw:345)
# INFO  @ Thu, 21 Dec 2023 07:40:58:    7 : keep.source term verbatim pdf  (output_test_summary.Rnw:489)
# INFO  @ Thu, 21 Dec 2023 07:40:58:    8 : keep.source term verbatim (output_test_summary.Rnw:567)
# INFO  @ Thu, 21 Dec 2023 07:40:58:    9 : keep.source term verbatim pdf  (output_test_summary.Rnw:573)
# INFO  @ Thu, 21 Dec 2023 07:40:58:   10 : keep.source term verbatim pdf  (output_test_summary.Rnw:691)
# INFO  @ Thu, 21 Dec 2023 07:40:58:   11 : keep.source term verbatim pdf  (output_test_summary.Rnw:835)
# INFO  @ Thu, 21 Dec 2023 07:40:58:   12 : keep.source term verbatim pdf  (output_test_summary.Rnw:979)
# INFO  @ Thu, 21 Dec 2023 07:40:58:
# INFO  @ Thu, 21 Dec 2023 07:40:58:   You can now run (pdf)latex on ‘output_test_summary.tex’
# INFO  @ Thu, 21 Dec 2023 07:40:58:   Error in texi2dvi("output_test_summary.tex", pdf = TRUE) :
# INFO  @ Thu, 21 Dec 2023 07:40:58:     pdflatex is not available
# INFO  @ Thu, 21 Dec 2023 07:40:58:   In addition: Warning message:
# INFO  @ Thu, 21 Dec 2023 07:40:58:   In texi2dvi("output_test_summary.tex", pdf = TRUE) :
# INFO  @ Thu, 21 Dec 2023 07:40:58:     texi2dvi script/program not available, using emulation
# INFO  @ Thu, 21 Dec 2023 07:40:58:   Execution halted
# INFO  @ Thu, 21 Dec 2023 07:40:58:
# INFO  @ Thu, 21 Dec 2023 07:40:58: End command message.
# INFO  @ Thu, 21 Dec 2023 07:40:58: Running command: cd ./; rm -rf output_test_summary-*.pdf
# INFO  @ Thu, 21 Dec 2023 07:40:58: Command message:
# INFO  @ Thu, 21 Dec 2023 07:40:58:
# INFO  @ Thu, 21 Dec 2023 07:40:58: End command message.
# INFO  @ Thu, 21 Dec 2023 07:40:58: Running command: cd ./; rm -rf output_test_summary.aux
# INFO  @ Thu, 21 Dec 2023 07:40:58: Command message:
# INFO  @ Thu, 21 Dec 2023 07:40:58:
# INFO  @ Thu, 21 Dec 2023 07:40:58: End command message.
# INFO  @ Thu, 21 Dec 2023 07:40:58: Running command: cd ./; rm -rf output_test_summary.tex
# INFO  @ Thu, 21 Dec 2023 07:40:58: Command message:
# INFO  @ Thu, 21 Dec 2023 07:40:58:
# INFO  @ Thu, 21 Dec 2023 07:40:58: End command message.
# INFO  @ Thu, 21 Dec 2023 07:40:58: Running command: cd ./; rm -rf output_test_summary.toc
# INFO  @ Thu, 21 Dec 2023 07:40:58: Command message:
# INFO  @ Thu, 21 Dec 2023 07:40:58:
# INFO  @ Thu, 21 Dec 2023 07:40:58: End command message.

# %% [markdown]
# Inspect the MAGeCK test files (sgRNA summary, gene summary and PDF report).

# %% [markdown]
# __sgRNA summary__
#
# Used to check how the individual guides for the genes of interest performed.

# %%
sgRNA_summary = pd.read_table('testing/output_test.sgrna_summary.txt')
sgRNA_summary.shape
# Out:
# (77441, 15)

# %%
sgRNA_summary.head(10)
# Out:
#       sgrna       Gene  control_count  treatment_count  control_mean  \
# 0  ID_73563  LOC554223      677.86000         5228.600     677.86000
# 1  ID_24663      NRXN1      126.11000         1733.900     126.11000
# 2  ID_28115      ACAA2      175.38000         2000.500     175.38000
# 3  ID_38719     AMOTL2       44.33700          829.760      44.33700
# 4  ID_33954      RPL36        0.00000           67.166       0.98527
# 5  ID_24933     EIF4E2        0.98527           66.133       0.98527
# 6  ID_30112     PRSS23      389.18000         2237.200     389.18000
# 7   ID_4797        DLD        0.00000           51.666       0.98527
# 8  ID_75745     PET117        0.00000           50.633       0.98527
# 9  ID_32417     NCAPD3        0.98527           48.566       0.98527
#
#    treat_mean     LFC  control_var    adj_var   score  p.low         p.high  \
# 0    5228.600  2.9455   10355000.0  6690.3000  55.637    1.0   0.000000e+00
# 1    1733.900  3.7707    1292500.0   883.5100  54.091    1.0   0.000000e+00
# 2    2000.500  3.5044    1665600.0  1312.3000  50.382    1.0   0.000000e+00
# 3     829.760  4.1957     308450.0   253.3000  49.350    1.0   0.000000e+00
# 4      67.166  5.1017       2255.6     2.9063  38.821    1.0   0.000000e+00
# 5      66.133  5.0796       2122.1     2.9063  38.215    1.0  1.121381e-319
# 6    2237.200  2.5201    1707500.0  3424.3000  31.580    1.0  3.517300e-219
# 7      51.666  4.7295       1334.7     2.9063  29.729    1.0  2.273400e-194
# 8      50.633  4.7009       1281.8     2.9063  29.123    1.0  1.293100e-186
# 9      48.566  4.6420       1132.0     2.9063  27.910    1.0  1.391300e-171
#
#       p.twosided            FDR  high_in_treatment
# 0   0.000000e+00   0.000000e+00               True
# 1   0.000000e+00   0.000000e+00               True
# 2   0.000000e+00   0.000000e+00               True
# 3   0.000000e+00   0.000000e+00               True
# 4   0.000000e+00   0.000000e+00               True
# 5  2.242910e-319  2.894800e-315               True
# 6  7.034600e-219  7.782400e-215               True
# 7  4.546900e-194  4.401400e-190               True
# 8  2.586200e-186  2.225300e-182               True
# 9  2.782700e-171  2.154900e-167               True

# %%
sgRNA_summary.columns
# Out:
# Index(['sgrna', 'Gene', 'control_count', 'treatment_count', 'control_mean',
#        'treat_mean', 'LFC', 'control_var', 'adj_var', 'score', 'p.low',
#        'p.high', 'p.twosided', 'FDR', 'high_in_treatment'],
#       dtype='object')

# %%
sgRNA_summary_info= {'Column_name': sgRNA_summary.columns, 
                     'Content': ['sgRNA ID', 
                                 'The targeting gene', 
                                 'Normalized read counts in control samples', 
                                 'Normalized read counts in treatment samples',
                                 'Mean read counts in control samples', 
                                 'Mean read counts in treatment samples',
                                 'The log2 fold change of sgRNA',
                                 'The raw variance in control samples',
                                 'The adjusted variance in control samples',
                                 'The score of this sgRNA',
                                 'p-value (lower tail)',
                                 'p-value (higher tail',
                                 'p-value (two-sided)',
                                 'False discovery rate',
                                 'Whether the abundance is higher in treatment samples'
                                ]}
pd.DataFrame.from_dict(sgRNA_summary_info)
# Out:
#           Column_name                                            Content
# 0               sgrna                                           sgRNA ID
# 1                Gene                                 The targeting gene
# 2       control_count          Normalized read counts in control samples
# 3     treatment_count        Normalized read counts in treatment samples
# 4        control_mean                Mean read counts in control samples
# 5          treat_mean              Mean read counts in treatment samples
# 6                 LFC                      The log2 fold change of sgRNA
# 7         control_var                The raw variance in control samples
# 8             adj_var           The adjusted variance in control samples
# 9               score                            The score of this sgRNA
# 10              p.low                               p-value (lower tail)
# 11             p.high                               p-value (higher tail
# 12         p.twosided                                p-value (two-sided)
# 13                FDR                               False discovery rate
# 14  high_in_treatment  Whether the abundance is higher in treatment s...

# %% [markdown]
# __Gene summary__
#
# The gene summary file contains a row for each gene targeted by sgRNAs ranked by the p.neg field (by default). The values are for both negative and positive selection. There are >20,000 genes in the file for this dataset from a negative selection screen so we negative values are of most interest.

# %%
gene_summary = pd.read_table('testing/output_test.gene_summary.txt')
gene_summary.shape
# Out:
# (20103, 14)

# %%
gene_summary.head(10)
# Out:
#          id  num  neg|score  neg|p-value   neg|fdr  neg|rank  neg|goodsgrna  \
# 0       ESD    4   0.000007     0.000019  0.324257         1              4
# 1   MTHFD1L    4   0.000010     0.000032  0.324257         2              4
# 2     SHMT2    4   0.000021     0.000076  0.454208         3              4
# 3      FLI1    4   0.000026     0.000090  0.454208         4              1
# 4     TACC3    4   0.000035     0.000121  0.486139         5              2
# 5     ACYP1    4   0.000079     0.000298  0.767027         6              2
# 6     SYNRG    4   0.000098     0.000369  0.767027         7              3
# 7  KIAA1468    4   0.000110     0.000413  0.767027         8              4
# 8   ZMYND11    3   0.000118     0.000361  0.767027         9              3
# 9   B3GALTL    4   0.000131     0.000498  0.767027        10              3
#
#    neg|lfc  pos|score  pos|p-value   pos|fdr  pos|rank  pos|goodsgrna  pos|lfc
# 0 -1.92830   0.995120      0.99512  0.999775     20004              0 -1.92830
# 1 -0.89778   0.999990      0.99999  0.999991     20103              0 -0.89778
# 2 -1.13280   0.999980      0.99998  0.999991     20102              0 -1.13280
# 3 -0.08872   0.337410      0.48212  0.999775      9461              1 -0.08872
# 4 -0.75335   0.075059      0.16968  0.998666      3241              2 -0.75335
# 5 -0.13267   0.413280      0.55952  0.999775     10986              1 -0.13267
# 6 -1.25300   0.244650      0.38823  0.999603      7600              1 -1.25300
# 7 -0.70376   0.999890      0.99990  0.999991     20101              0 -0.70376
# 8 -0.78281   0.999880      0.99988  0.999991     20100              0 -0.78281
# 9 -0.27607   0.964200      0.96411  0.999775     19342              0 -0.27607

# %%
gene_summary.columns
# Out:
# Index(['id', 'num', 'neg|score', 'neg|p-value', 'neg|fdr', 'neg|rank',
#        'neg|goodsgrna', 'neg|lfc', 'pos|score', 'pos|p-value', 'pos|fdr',
#        'pos|rank', 'pos|goodsgrna', 'pos|lfc'],
#       dtype='object')

# %%
gene_summary_info = {'Column_name': gene_summary.columns, 
                     'Content': ['Gene ID', 
                                 'The number of targeting sgRNAs for each gene', 
                                 'The RRA lo value of this gene in negative selection', 
                                 'The raw p-value (using permutation) of this gene in negative selection',
                                 'The false discovery rate for this gene in negative selection', 
                                 'The ranking of this gene in negative selection',
                                 'The number of good sgRNA - those whose ranking is below the alpha cutoff (determined by the -gene-test-fdr-threshold option, in negative selection',
                                 'The log2 fold change of this gene in negative selection. Gene lfc calculation is controlled by the -gene-lfc-method option',
                                 'The RRA lo value of this gene in positive selection', 
                                 'The raw p-value (using permutation) of this gene in positive selection',
                                 'The false discovery rate for this gene in positive selection', 
                                 'The ranking of this gene in positive selection',
                                 'The number of good sgRNA - those whose ranking is below the alpha cutoff (determined by the -gene-test-fdr-threshold option, in positive selection',
                                 'The log2 fold change of this gene in positive selection'
                                 ]}
pd.DataFrame.from_dict(gene_summary_info)
# Out:
#       Column_name                                            Content
# 0              id                                            Gene ID
# 1             num       The number of targeting sgRNAs for each gene
# 2       neg|score  The RRA lo value of this gene in negative sele...
# 3     neg|p-value  The raw p-value (using permutation) of this ge...
# 4         neg|fdr  The false discovery rate for this gene in nega...
# 5        neg|rank     The ranking of this gene in negative selection
# 6   neg|goodsgrna  The number of good sgRNA - those whose ranking...
# 7         neg|lfc  The log2 fold change of this gene in negative ...
# 8       pos|score  The RRA lo value of this gene in positive sele...
# 9     pos|p-value  The raw p-value (using permutation) of this ge...
# 10        pos|fdr  The false discovery rate for this gene in posi...
# 11       pos|rank     The ranking of this gene in positive selection
# 12  pos|goodsgrna  The number of good sgRNA - those whose ranking...
# 13        pos|lfc  The log2 fold change of this gene in positive ...

# %% [markdown]
# __PDF report__
#
# [MAGeck test report](./testing/output_test.pdf)

# %%
from IPython.display import IFrame
IFrame("testing/output_test.pdf", width=600, height=300)
# Out:
#         <iframe
#             width="600"
#             height="300"
#             src="testing/output_test.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# The PDF shows plots of the top 10 negatively and positively selected genes.
# - The distribution plots show the top genes ranked by RRA scores or p values found in the gene summary file. The top 3 negatively selected genes: ESD, MTHFD1L and SHMT2 have similar RRA/p-value scores and are invloved in the glutathione (GSH) pathway and mitochondrial metabolism in determining APR-246 efficacy/sensitivity. APR-246 triggers GSH depletion in cancer cells, and its sensitivity is increased through loss of key enzymes in mitochondrial one-carbon metabolism.
# - The plots with the sgRNA counts for the top 10 genes show whether the counts of all the sgRNAs for the top genes are changing similarly. The values are the normalized counts for each sgRNA from the sgRNA summary file.

# %% [markdown]
# #### Visualisation
#
# In addition to the visualisations automatically generated by MAGeCK in the PDF, the output can be further visualised with a volcano plot to plot the magnitude of change for drug treatment versus vehicle control (lfc) versus significance (p-value). As the gene summary file contains two columns for lfc and p-value, one for negative selection and one for positive, these two columns are combined into one for each gene using __awk__. If the `neg|p-value` is smaller than the `pos|p-value` the gene is negatively selected. If the `neg|p-value` is larger than the `pos|p-value` the gene is positively selected.

# %%
! $(which awk) -v FS='	' \
      -v OFS='	' \
      -f scripts/awk.script testing/output_test.gene_summary.txt > testing/output_test.reformatted.gene_summary.txt

# %%
! cat scripts/awk.script
# Out:
# # Print new header for first line
# NR == 1 { print "gene", "pval", "fdr", "lfc" }
#
# # Only process lines after first
# NR > 1 {
#     # check if neg pval (column 4) is less than pos pval (column 10)
#     if ($4 < $10){
#        # if it is, print negative selection values
#         print $1, $4, $5, $8
#     } else {
#        # if it's not, print positive selection values
#         print $1, $10, $11, $14
#     }
# }

# %%
gene_summary_trf = pd.read_table('testing/output_test.reformatted.gene_summary.txt')
gene_summary_trf.head(10)
# Out:
#        gene      pval       fdr      lfc
# 0       ESD  0.000019  0.324257 -1.92830
# 1   MTHFD1L  0.000032  0.324257 -0.89778
# 2     SHMT2  0.000076  0.454208 -1.13280
# 3      FLI1  0.000090  0.454208 -0.08872
# 4     TACC3  0.000121  0.486139 -0.75335
# 5     ACYP1  0.000298  0.767027 -0.13267
# 6     SYNRG  0.000369  0.767027 -1.25300
# 7  KIAA1468  0.000413  0.767027 -0.70376
# 8   ZMYND11  0.000361  0.767027 -0.78281
# 9   B3GALTL  0.000498  0.767027 -0.27607

# %%
! Rscript scripts/volcanoplot.rscript --input testing/output_test.reformatted.gene_summary.txt \
--fdr_col 3 --pval_col 2 --lfc_col 4 --label_col 1 --signif_thresh 0.05 --lfc_thresh 0.0 --topn 10
# Out:
# null device
#           1
# [1] "Create volcano_plot.pdf....... DONE."

# %%
! cat scripts/volcanoplot.rscript
# Out:
# # Load packages -----------------------------------------------------------
#
# suppressPackageStartupMessages({
#     library(dplyr)
#     library(ggplot2)
#     library(ggrepel)
#     library(optparse)
# })
#
# # Fetch arguments  --------------------------------------------------------
#
# option_list = list(
#   make_option(c("-i", "--input"), action="store", default=NA, type='character',
#               help="input gene summary file"),
#   make_option(c("-a", "--fdr_col"), action="store", default=NA, type='integer',
#               help="FDR (adjusted p-value) column number"),
#   make_option(c("-p", "--pval_col"), action="store", default=NA, type='integer',
#               help="pvalue column number"),
#   make_option(c("-f", "--lfc_col"), action="store", default=NA, type='integer',
#               help="logfc column number"),
#   make_option(c("-l", "--label_col"), action="store", default=NA, type='integer',
#               help="labels column number"),
#   make_option(c("-s", "--signif_thresh"), action="store", default=NA, type='double',
#               help="significance threshold"),
#   make_option(c("-c", "--lfc_thresh"), action="store", default=NA, type='double',
#               help="log fold change threshold"),
#   make_option(c("-t", "--topn"), action="store", default=NA, type='integer',
#               help="number of top most significant genes to label")
# )
# opt = parse_args(OptionParser(option_list=option_list))
#
# # Read input  -------------------------------------------------------------
#
# results <- read.delim(opt$input, header = TRUE)
#
# # Format data  ------------------------------------------------------------
#
# # Create columns from the column numbers specified
# results <- results %>% mutate(fdr = .[[opt$fdr_col]],
#                               pvalue = .[[opt$pval_col]],
#                               logfc = .[[opt$lfc_col]],
#                               labels = .[[opt$label_col]])
#
# # Get names for legend
# down <- unlist(strsplit('Down,Not Sig,Up', split = ","))[1]
# notsig <- unlist(strsplit('Down,Not Sig,Up', split = ","))[2]
# up <- unlist(strsplit('Down,Not Sig,Up', split = ","))[3]
#
# # Set colours
# colours <- setNames(c("cornflowerblue", "grey", "firebrick"), c(down, notsig, up))
#
# # Create significant (sig) column
# results <- mutate(results, sig = case_when(
#                                 fdr < opt$signif_thresh & logfc > opt$lfc_thresh ~ up,
#                                 fdr < opt$signif_thresh & logfc < -opt$lfc_thresh ~ down,
#                                 TRUE ~ notsig))
#
#
# # Specify genes to label --------------------------------------------------
#
# # Get top genes by P value
# top <- slice_min(results, order_by = pvalue, n = opt$topn)
#
# # Extract into vector
# toplabels <- pull(top, labels)
#
# # Label just the top genes in results table
# results <- mutate(results, labels = ifelse(labels %in% toplabels, labels, ""))
#
#
# # Create plot -------------------------------------------------------------
#
# # Open file to save plot as PDF
# pdf("volcano_plot.pdf")
#
# # Set up base plot
# p <- ggplot(data = results, aes(x = logfc, y = -log10(pvalue))) +
#     geom_point(aes(colour = sig)) +
#     scale_color_manual(values = colours) +
#     theme(panel.grid.major = element_blank(),
#         panel.grid.minor = element_blank(),
#         panel.background = element_blank(),
#         axis.line = element_line(colour = "black"),
#         legend.key = element_blank())
#
# # Add gene labels
# p <- p + geom_text_repel(data = filter(results, labels != ""), aes(label = labels),
#                          min.segment.length = 0,
#                          max.overlaps = Inf,
#                          show.legend = FALSE)
#
# # Set legend title
# p <- p + theme(legend.title = element_blank())
#
# # Print plot
# print(p)
#
# # Close PDF graphics device
# dev.off()
#
# print("Create volcano_plot.pdf....... DONE.")

# %% [markdown]
# [MAGeCK test volcano plot](./testing/volcano_plot.pdf)

# %%
from IPython.display import IFrame
IFrame("testing/volcano_plot.pdf", width=600, height=300)
# Out:
#         <iframe
#             width="600"
#             height="300"
#             src="testing/volcano_plot.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# #### Pathway analysis
#
# Use [__fgsea__](https://bioconductor.org/packages/devel/bioc/manuals/fgsea/man/fgsea.pdf) to perform pathway analysis on the results and identify pathways that are changing with the treatment. fgsea needs a ranked list of genes - the list from mageck gene summary result file ranked by `neg|score` - the RRA score column for negative results, and a pathways file in GMT format - the Hallmark pathways from MSigDB.

# %%
! cut -f 1,3 testing/output_test.gene_summary.txt > testing/output_test.cut.gene_summary.txt

# %%
pd.read_table('testing/output_test.cut.gene_summary.txt', delimiter='\t').head(10)
# Out:
#          id  neg|score
# 0       ESD   0.000007
# 1   MTHFD1L   0.000010
# 2     SHMT2   0.000021
# 3      FLI1   0.000026
# 4     TACC3   0.000035
# 5     ACYP1   0.000079
# 6     SYNRG   0.000098
# 7  KIAA1468   0.000110
# 8   ZMYND11   0.000118
# 9   B3GALTL   0.000131

# %%
! Rscript scripts/fgsea.R --rnk_file testing/output_test.cut.gene_summary.txt \
--header True --sets_file fgsea/hallmark.pathways.all.v7.4.symbols.gmt --gmt True \
--min_size 15 --max_size 500 --n_perm 1000 --out_tab fgsea/fgsea_pathways.txt \
--plot_opt True --top_num 10 --rda_opt True
# Out:
# Warning message:
# package ‘fgsea’ was built under R version 4.3.2
# Warning messages:
# 1: In preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam,  :
#   There are ties in the preranked stats (14.51% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.
# 2: In preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam,  :
#   All values in the stats vector are greater than zero and scoreType is "std", maybe you should switch to scoreType = "pos".
# [1] "Create fgsea_plots.pdf...... DOne."

# %%
! cat scripts/fgsea.R
# Out:
# suppressPackageStartupMessages({
#   library(fgsea)
#   library(ggplot2)
#   library(optparse)
# })
#
# option_list <- list(
#   make_option(c("-r", "--rnk_file"), type="character", help="Path to ranked genes file"),
#   make_option(c("-h", "--header"), type="logical", help = "Does ranked genes file have a header"),
#   make_option(c("-s", "--sets_file"), type="character", help = "Path to gene sets file"),
#   make_option(c("-g", "--gmt"), type="logical", help = "Is the sets file in GMT format"),
#   make_option(c("-o","--out_tab"), type="character", help="Path to output file"),
#   make_option(c("-m", "--min_size"), type="integer", help="Minimal size of a gene set to test. All pathways below the threshold are excluded."),
#   make_option(c("-x", "--max_size"), type="integer", help="Maximal size of a gene set to test. All pathways above the threshold are excluded."),
#   make_option(c("-n", "--n_perm"), type="integer", help="Number of permutations to do. Minimial possible nominal p-value is about 1/nperm"),
#   make_option(c("-d", "--rda_opt"), type="logical", help="Output RData file"),
#   make_option(c("-p", "--plot_opt"), type="logical", help="Output plot"),
#   make_option(c("-t", "--top_num"), type="integer", help="Top number of pathways to plot")
# )
#
# parser <- OptionParser(usage = "%prog [options] file", option_list=option_list, add_help_option=FALSE)
# args = parse_args(parser)
#
# rnk_file = args$rnk_file
# if (args$header) {
#   header = TRUE
# } else {
#   header = FALSE
# }
# sets_file = args$sets_file
# gmt = args$gmt
# out_tab = args$out_tab
# min_size = args$min_size
# max_size = args$max_size
# n_perm = args$n_perm
# rda_opt = args$rda_opt
# plot_opt = args$plot_opt
# top_num = args$top_num
#
# ## using the steps from the fgsea vignette
# rankTab <- read.table(rnk_file, header=header, colClasses = c("character", "numeric"))
#
# ranks <-rankTab[,2]
# names(ranks) <- rankTab[,1]
#
# if (gmt) {
#   pathways <- gmtPathways(sets_file)
# } else {
#   pathways <- load(sets_file)
#   pathways <- get(pathways)
# }
#
# # set seed for reproducibility https://github.com/ctlab/fgsea/issues/12
# set.seed(42)
# fgseaRes <- fgsea(pathways, ranks, minSize=min_size, maxSize=max_size)
# fgseaRes <- fgseaRes[order(pval), ]
# # convert leadingEdge column from list to character to output
# fgseaRes$leadingEdge <- sapply(fgseaRes$leadingEdge, toString)
#
# write.table(fgseaRes, out_tab, sep="\t", row.names=FALSE, quote=FALSE)
#
# if (plot_opt) {
#   pdf("fgsea_plots.pdf", width=8)
#
#   topPathways <- head(fgseaRes, n=top_num)
#   topPathways <- topPathways$pathway
#
#   ## make summary table plot for top pathways
#   p <- plotGseaTable(pathways[topPathways], ranks, fgseaRes, gseaParam = 0.5,
#   colwidths = c(5.3,3,0.7, 0.9, 0.9))
#   print(p)
#
#   # make enrichment plots for top pathways
#   for (i in topPathways) {
#     p <- plotEnrichment(pathways[[i]], ranks) + labs(title=i)
#     print(p)
#   }
#
#   dev.off()
#
#   print("Create fgsea_plots.pdf...... DOne.")
# }
#
# ## output RData file
# if (rda_opt) {
#     save.image(file = "fgsea_analysis.RData")
# }

# %%
pd.read_table('fgsea/fgsea_pathways.txt', delimiter='\t').head(10)
# Out:
#                                     pathway      pval      padj   log2err  \
# 0        HALLMARK_OXIDATIVE_PHOSPHORYLATION  0.002719  0.078159  0.431708
# 1                   HALLMARK_UV_RESPONSE_DN  0.003126  0.078159  0.431708
# 2                       HALLMARK_PEROXISOME  0.016071  0.267852  0.352488
# 3                       HALLMARK_GLYCOLYSIS  0.034965  0.437063  0.241340
# 4            HALLMARK_FATTY_ACID_METABOLISM  0.044955  0.449550  0.211400
# 5  HALLMARK_REACTIVE_OXYGEN_SPECIES_PATHWAY  0.079920  0.585129  0.155242
# 6                   HALLMARK_APICAL_SURFACE  0.081918  0.585129  0.153159
# 7             HALLMARK_BILE_ACID_METABOLISM  0.105894  0.599401  0.132846
# 8              HALLMARK_IL2_STAT5_SIGNALING  0.107892  0.599401  0.131458
# 9                     HALLMARK_ADIPOGENESIS  0.147852  0.699301  0.109684
#
#          ES       NES  size                                        leadingEdge
# 0  0.422450  1.217541   184  CS, PDHB, NDUFS7, NDUFB7, COX7B, NDUFA9, MRPS1...
# 1  0.430468  1.226789   138  ABCC1, GCNT1, ADD3, SIPA1L1, NFKB1, SERPINE1, ...
# 2  0.431720  1.210982   104  CRABP2, SLC25A19, FADS1, PEX11A, CADM1, IDH1, ...
# 3  0.395600  1.142261   197  ARPP19, GAL3ST1, P4HA2, HDLBP, B3GAT1, VCAN, I...
# 4  0.400885  1.147461   155  PDHB, PPARA, IDH1, HSP90AA1, HSD17B4, FABP1, P...
# 5  0.449017  1.201711    47  ABCC1, MPO, NDUFS2, CDKN2D, PRDX6, STK25, HMOX...
# 6  0.456963  1.217509    43  LYN, ADAM10, FLOT2, CROCC, APP, NTNG1, LYPD3, ...
# 7  0.399053  1.125537   112  FADS1, PEX11A, AGXT, IDH1, SLC27A5, GNPAT, HSD...
# 8  0.381330  1.100535   194  MXD1, GPR83, NDRG1, WLS, TGM2, CST7, SWAP70, B...
# 9  0.375415  1.083243   192  CS, ANGPT1, NDUFB7, COX7B, GPHN, NKIRAS1, COQ5...

# %% [markdown]
# [FGSEA plots](./fgsea/fgsea_plots.pdf)

# %%
from IPython.display import IFrame
IFrame("fgsea/fgsea_plots.pdf", width=600, height=300)
# Out:
#         <iframe
#             width="600"
#             height="300"
#             src="fgsea/fgsea_plots.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# #### Multiple conditions
#
# Use __MAGeck mle__ to compare multiple conditions: the drug treatment (T8-APR-246) to T0-COntrol and the vehicle (T8-Vehicle) to T0-Control.
#
# MAGeCK mle uses a maximum likelihood estimation (MLE) algorithm. It outputs a single value (beta score) per gene instead of a score for both negative and positive selection. A negative beta score indicates negative selection and a positive indicates positive selection. MAGeCK mle can also be used for comparing 2 conditions instead of MAGeCK test (RRA algorithm) but it is slower.
#
# A MAGeCK mle run requires the MAGeCK sgRNA counts and a design matrix.
#
# Design matrix for 3 conditions: baseline (T0), Vehicle and APR. The 1st row indicates that T0 is baseline sample, the 2nd row indicates Vehicle to T0 comparison, and the 3rd row indicates APR to T0 comparison.
#
# For MAGeCK mle the design matrix:
#
# - must include a header line of condition labels
# - the first column is the sample labels that must match labels in read count file
# - the second column must be a “baseline” column that sets all values to “1”
# - the value in the design matrix is either “0” or “1”
# - must have at least one sample of “initial state” (e.g., time 0) that has only one “1” in the corresponding row. That only “1” must be in the baseline column
# - the initial state (baseline) sample must be the 1st sample listed, under the header row.

# %%
design_matrix = pd.read_csv("mle/full_mageck_mle_design_matrix.tsv", delimiter="\t")
design_matrix
# Out:
#       Samples  baseline  Vehicle  APR
# 0  T0-Control         1        0    0
# 1  T8-Vehicle         1        1    0
# 2  T8-APR-246         1        0    1

# %%
! mageck mle -k counting/full_mageck_sgrna_counts.tsv -d mle/full_mageck_mle_design_matrix.tsv \
-n output_mle --norm-method median --threads 4
# Out:
# INFO  @ Thu, 21 Dec 2023 07:44:27: Parameters: /usr/local/bin/mageck mle -k counting/full_mageck_sgrna_counts.tsv -d mle/full_mageck_mle_design_matrix.tsv -n output_mle --norm-method median --threads 4
# INFO  @ Thu, 21 Dec 2023 07:44:27: Cannot parse design matrix as a string; try to parse it as a file name ...
# INFO  @ Thu, 21 Dec 2023 07:44:27: Design matrix:
# INFO  @ Thu, 21 Dec 2023 07:44:27: [[1. 0. 0.]
# INFO  @ Thu, 21 Dec 2023 07:44:27:  [1. 1. 0.]
# INFO  @ Thu, 21 Dec 2023 07:44:27:  [1. 0. 1.]]
# INFO  @ Thu, 21 Dec 2023 07:44:27: Beta labels:baseline,Vehicle,APR
# INFO  @ Thu, 21 Dec 2023 07:44:27: Included samples:T0-Control,T8-Vehicle,T8-APR-246
# INFO  @ Thu, 21 Dec 2023 07:44:27: Loaded samples:T0-Control;T8-Vehicle;T8-APR-246
# INFO  @ Thu, 21 Dec 2023 07:44:27: Sample index: 2;1;0
# INFO  @ Thu, 21 Dec 2023 07:44:27: Loaded 20112 genes.
# INFO  @ Thu, 21 Dec 2023 07:44:28: Final size factor: 0.8688780183350758 1.0565381424478189 1.1107589343544333
# INFO  @ Thu, 21 Dec 2023 07:44:28: size factor: 1.150909539541784,0.946487362664608,0.9002853536183296
# INFO  @ Thu, 21 Dec 2023 07:44:29: Thread 0 started.
# INFO  @ Thu, 21 Dec 2023 07:44:29: Thread 0: total 1 instances.
# INFO  @ Thu, 21 Dec 2023 07:44:29: Thread 1 started.
# INFO  @ Thu, 21 Dec 2023 07:44:29: Thread 1: total 0 instances.
# INFO  @ Thu, 21 Dec 2023 07:44:29: Thread 2 started.
# INFO  @ Thu, 21 Dec 2023 07:44:29: Thread 2: total 0 instances.
# INFO  @ Thu, 21 Dec 2023 07:44:29: Thread 3 started.
# INFO  @ Thu, 21 Dec 2023 07:44:29: Thread 3: total 0 instances.
# INFO  @ Thu, 21 Dec 2023 07:44:29: Thread 0 completed.
# INFO  @ Thu, 21 Dec 2023 07:44:29: Thread 1 completed.
# INFO  @ Thu, 21 Dec 2023 07:44:29: Thread 2 completed.
# INFO  @ Thu, 21 Dec 2023 07:44:29: Thread 3 completed.
# INFO  @ Thu, 21 Dec 2023 07:44:29: All threads completed.
# INFO  @ Thu, 21 Dec 2023 07:44:29: Modeling the mean and variance ...
# INFO  @ Thu, 21 Dec 2023 07:44:29: Run the algorithm for the second time ...
# INFO  @ Thu, 21 Dec 2023 07:44:29: Thread 0 started.
# INFO  @ Thu, 21 Dec 2023 07:44:29: Thread 0: total 5028 instances.
# INFO  @ Thu, 21 Dec 2023 07:44:29: Thread 1 started.
# INFO  @ Thu, 21 Dec 2023 07:44:29: Thread 1: total 5028 instances.
# INFO  @ Thu, 21 Dec 2023 07:44:29: Thread 2 started.
# INFO  @ Thu, 21 Dec 2023 07:44:29: Thread 2: total 5028 instances.
# INFO  @ Thu, 21 Dec 2023 07:44:29: Thread 3 started.
# INFO  @ Thu, 21 Dec 2023 07:44:29: Thread 3: total 5028 instances.
# INFO  @ Thu, 21 Dec 2023 07:44:29: Thread 0: Calculating PIP5K1B (1) ...
# INFO  @ Thu, 21 Dec 2023 07:44:29: Thread 1: Calculating controlguide578 (1) ...
# INFO  @ Thu, 21 Dec 2023 07:44:29: Thread 2: Calculating GALNT12 (1) ...
# INFO  @ Thu, 21 Dec 2023 07:44:29: Thread 3: Calculating MAP7 (1) ...
# INFO  @ Thu, 21 Dec 2023 07:44:33: Thread 0: Calculating TRIP11 (1001) ...
# INFO  @ Thu, 21 Dec 2023 07:44:33: Thread 2: Calculating PASD1 (1001) ...
# INFO  @ Thu, 21 Dec 2023 07:44:33: Thread 1: Calculating EFHD1 (1001) ...
# INFO  @ Thu, 21 Dec 2023 07:44:34: Thread 3: Calculating WI2-2373I1.2 (1001) ...
# INFO  @ Thu, 21 Dec 2023 07:44:38: Thread 0: Calculating TMEM181 (2001) ...
# INFO  @ Thu, 21 Dec 2023 07:44:38: Thread 2: Calculating CLCF1 (2001) ...
# INFO  @ Thu, 21 Dec 2023 07:44:38: Thread 3: Calculating HINT1 (2001) ...
# INFO  @ Thu, 21 Dec 2023 07:44:38: Thread 1: Calculating FAM133B (2001) ...
# INFO  @ Thu, 21 Dec 2023 07:44:42: Thread 0: Calculating ADGRL2 (3001) ...
# INFO  @ Thu, 21 Dec 2023 07:44:43: Thread 2: Calculating TJP3 (3001) ...
# INFO  @ Thu, 21 Dec 2023 07:44:43: Thread 3: Calculating ALOX12 (3001) ...
# INFO  @ Thu, 21 Dec 2023 07:44:43: Thread 1: Calculating controlguide609 (3001) ...
# INFO  @ Thu, 21 Dec 2023 07:44:47: Thread 0: Calculating PZP (4001) ...
# INFO  @ Thu, 21 Dec 2023 07:44:47: Thread 2: Calculating EIF3M (4001) ...
# INFO  @ Thu, 21 Dec 2023 07:44:47: Thread 3: Calculating CHRM5 (4001) ...
# INFO  @ Thu, 21 Dec 2023 07:44:47: Thread 1: Calculating DAZ2 (4001) ...
# INFO  @ Thu, 21 Dec 2023 07:44:51: Thread 0: Calculating TXN2 (5001) ...
# INFO  @ Thu, 21 Dec 2023 07:44:52: Thread 0 completed.
# INFO  @ Thu, 21 Dec 2023 07:44:52: Thread 1: Calculating CCT7 (5001) ...
# INFO  @ Thu, 21 Dec 2023 07:44:52: Thread 3: Calculating NBPF15 (5001) ...
# INFO  @ Thu, 21 Dec 2023 07:44:52: Thread 2: Calculating PLK1 (5001) ...
# INFO  @ Thu, 21 Dec 2023 07:44:52: Thread 1 completed.
# INFO  @ Thu, 21 Dec 2023 07:44:52: Thread 2 completed.
# INFO  @ Thu, 21 Dec 2023 07:44:52: Thread 3 completed.
# INFO  @ Thu, 21 Dec 2023 07:44:52: All threads completed.
# INFO  @ Thu, 21 Dec 2023 07:44:56: Permuting groups of gene with 1 sgRNAs per gene. Group progress: 1/4
# INFO  @ Thu, 21 Dec 2023 07:44:56: Start permuting 2 rounds ...
# INFO  @ Thu, 21 Dec 2023 07:44:56: Collecting 77441 sgRNAs from 20112 genes.
# INFO  @ Thu, 21 Dec 2023 07:44:58: Permuting round 0 ...
# INFO  @ Thu, 21 Dec 2023 07:44:58: Thread 0 started.
# INFO  @ Thu, 21 Dec 2023 07:44:58: Thread 0: total 5028 instances.
# INFO  @ Thu, 21 Dec 2023 07:44:58: Thread 1 started.
# INFO  @ Thu, 21 Dec 2023 07:44:58: Thread 1: total 5028 instances.
# INFO  @ Thu, 21 Dec 2023 07:44:58: Thread 2 started.
# INFO  @ Thu, 21 Dec 2023 07:44:58: Thread 2: total 5028 instances.
# INFO  @ Thu, 21 Dec 2023 07:44:58: Thread 3 started.
# INFO  @ Thu, 21 Dec 2023 07:44:58: Thread 3: total 5028 instances.
# INFO  @ Thu, 21 Dec 2023 07:44:58: Thread 0: Calculating PIP5K1B (1) ...
# INFO  @ Thu, 21 Dec 2023 07:44:58: Thread 1: Calculating controlguide578 (1) ...
# INFO  @ Thu, 21 Dec 2023 07:44:58: Thread 2: Calculating GALNT12 (1) ...
# INFO  @ Thu, 21 Dec 2023 07:44:58: Thread 3: Calculating MAP7 (1) ...
# INFO  @ Thu, 21 Dec 2023 07:45:01: Thread 2: Calculating PASD1 (1001) ...
# INFO  @ Thu, 21 Dec 2023 07:45:02: Thread 0: Calculating TRIP11 (1001) ...
# INFO  @ Thu, 21 Dec 2023 07:45:02: Thread 1: Calculating EFHD1 (1001) ...
# INFO  @ Thu, 21 Dec 2023 07:45:02: Thread 3: Calculating WI2-2373I1.2 (1001) ...
# INFO  @ Thu, 21 Dec 2023 07:45:04: Thread 2: Calculating CLCF1 (2001) ...
# INFO  @ Thu, 21 Dec 2023 07:45:04: Thread 1: Calculating FAM133B (2001) ...
# INFO  @ Thu, 21 Dec 2023 07:45:04: Thread 0: Calculating TMEM181 (2001) ...
# INFO  @ Thu, 21 Dec 2023 07:45:05: Thread 3: Calculating HINT1 (2001) ...
# INFO  @ Thu, 21 Dec 2023 07:45:07: Thread 2: Calculating TJP3 (3001) ...
# INFO  @ Thu, 21 Dec 2023 07:45:07: Thread 1: Calculating controlguide609 (3001) ...
# INFO  @ Thu, 21 Dec 2023 07:45:07: Thread 0: Calculating ADGRL2 (3001) ...
# INFO  @ Thu, 21 Dec 2023 07:45:07: Thread 3: Calculating ALOX12 (3001) ...
# INFO  @ Thu, 21 Dec 2023 07:45:10: Thread 1: Calculating DAZ2 (4001) ...
# INFO  @ Thu, 21 Dec 2023 07:45:10: Thread 0: Calculating PZP (4001) ...
# INFO  @ Thu, 21 Dec 2023 07:45:10: Thread 2: Calculating EIF3M (4001) ...
# INFO  @ Thu, 21 Dec 2023 07:45:10: Thread 3: Calculating CHRM5 (4001) ...
# INFO  @ Thu, 21 Dec 2023 07:45:13: Thread 1: Calculating CCT7 (5001) ...
# INFO  @ Thu, 21 Dec 2023 07:45:13: Thread 0: Calculating TXN2 (5001) ...
# INFO  @ Thu, 21 Dec 2023 07:45:13: Thread 2: Calculating PLK1 (5001) ...
# INFO  @ Thu, 21 Dec 2023 07:45:13: Thread 3: Calculating NBPF15 (5001) ...
# INFO  @ Thu, 21 Dec 2023 07:45:13: Thread 0 completed.
# INFO  @ Thu, 21 Dec 2023 07:45:13: Thread 1 completed.
# INFO  @ Thu, 21 Dec 2023 07:45:14: Thread 2 completed.
# INFO  @ Thu, 21 Dec 2023 07:45:14: Thread 3 completed.
# INFO  @ Thu, 21 Dec 2023 07:45:14: All threads completed.
# INFO  @ Thu, 21 Dec 2023 07:45:18: Permuting round 1 ...
# INFO  @ Thu, 21 Dec 2023 07:45:18: Thread 0 started.
# INFO  @ Thu, 21 Dec 2023 07:45:18: Thread 0: total 5028 instances.
# INFO  @ Thu, 21 Dec 2023 07:45:18: Thread 1 started.
# INFO  @ Thu, 21 Dec 2023 07:45:18: Thread 1: total 5028 instances.
# INFO  @ Thu, 21 Dec 2023 07:45:18: Thread 2 started.
# INFO  @ Thu, 21 Dec 2023 07:45:18: Thread 2: total 5028 instances.
# INFO  @ Thu, 21 Dec 2023 07:45:18: Thread 3 started.
# INFO  @ Thu, 21 Dec 2023 07:45:18: Thread 3: total 5028 instances.
# INFO  @ Thu, 21 Dec 2023 07:45:18: Thread 0: Calculating PIP5K1B (1) ...
# INFO  @ Thu, 21 Dec 2023 07:45:18: Thread 1: Calculating controlguide578 (1) ...
# INFO  @ Thu, 21 Dec 2023 07:45:18: Thread 2: Calculating GALNT12 (1) ...
# INFO  @ Thu, 21 Dec 2023 07:45:18: Thread 3: Calculating MAP7 (1) ...
# INFO  @ Thu, 21 Dec 2023 07:45:21: Thread 1: Calculating EFHD1 (1001) ...
# INFO  @ Thu, 21 Dec 2023 07:45:21: Thread 2: Calculating PASD1 (1001) ...
# INFO  @ Thu, 21 Dec 2023 07:45:22: Thread 0: Calculating TRIP11 (1001) ...
# INFO  @ Thu, 21 Dec 2023 07:45:22: Thread 3: Calculating WI2-2373I1.2 (1001) ...
# INFO  @ Thu, 21 Dec 2023 07:45:25: Thread 2: Calculating CLCF1 (2001) ...
# INFO  @ Thu, 21 Dec 2023 07:45:25: Thread 1: Calculating FAM133B (2001) ...
# INFO  @ Thu, 21 Dec 2023 07:45:25: Thread 0: Calculating TMEM181 (2001) ...
# INFO  @ Thu, 21 Dec 2023 07:45:25: Thread 3: Calculating HINT1 (2001) ...
# INFO  @ Thu, 21 Dec 2023 07:45:28: Thread 2: Calculating TJP3 (3001) ...
# INFO  @ Thu, 21 Dec 2023 07:45:28: Thread 1: Calculating controlguide609 (3001) ...
# INFO  @ Thu, 21 Dec 2023 07:45:28: Thread 0: Calculating ADGRL2 (3001) ...
# INFO  @ Thu, 21 Dec 2023 07:45:28: Thread 3: Calculating ALOX12 (3001) ...
# INFO  @ Thu, 21 Dec 2023 07:45:31: Thread 2: Calculating EIF3M (4001) ...
# INFO  @ Thu, 21 Dec 2023 07:45:31: Thread 1: Calculating DAZ2 (4001) ...
# INFO  @ Thu, 21 Dec 2023 07:45:31: Thread 0: Calculating PZP (4001) ...
# INFO  @ Thu, 21 Dec 2023 07:45:31: Thread 3: Calculating CHRM5 (4001) ...
# INFO  @ Thu, 21 Dec 2023 07:45:33: Thread 2: Calculating PLK1 (5001) ...
# INFO  @ Thu, 21 Dec 2023 07:45:34: Thread 1: Calculating CCT7 (5001) ...
# INFO  @ Thu, 21 Dec 2023 07:45:34: Thread 0: Calculating TXN2 (5001) ...
# INFO  @ Thu, 21 Dec 2023 07:45:34: Thread 3: Calculating NBPF15 (5001) ...
# INFO  @ Thu, 21 Dec 2023 07:45:34: Thread 0 completed.
# INFO  @ Thu, 21 Dec 2023 07:45:34: Thread 1 completed.
# INFO  @ Thu, 21 Dec 2023 07:45:34: Thread 2 completed.
# INFO  @ Thu, 21 Dec 2023 07:45:34: Thread 3 completed.
# INFO  @ Thu, 21 Dec 2023 07:45:34: All threads completed.
# INFO  @ Thu, 21 Dec 2023 07:45:38: Assigning p values...
# INFO  @ Thu, 21 Dec 2023 07:45:40: Permuting groups of gene with 2 sgRNAs per gene. Group progress: 2/4
# INFO  @ Thu, 21 Dec 2023 07:45:40: Start permuting 2 rounds ...
# INFO  @ Thu, 21 Dec 2023 07:45:41: Collecting 77441 sgRNAs from 20112 genes.
# INFO  @ Thu, 21 Dec 2023 07:45:42: Permuting round 0 ...
# INFO  @ Thu, 21 Dec 2023 07:45:43: Thread 0 started.
# INFO  @ Thu, 21 Dec 2023 07:45:43: Thread 0: total 5028 instances.
# INFO  @ Thu, 21 Dec 2023 07:45:43: Thread 1 started.
# INFO  @ Thu, 21 Dec 2023 07:45:43: Thread 1: total 5028 instances.
# INFO  @ Thu, 21 Dec 2023 07:45:43: Thread 2 started.
# INFO  @ Thu, 21 Dec 2023 07:45:43: Thread 2: total 5028 instances.
# INFO  @ Thu, 21 Dec 2023 07:45:43: Thread 3 started.
# INFO  @ Thu, 21 Dec 2023 07:45:43: Thread 0: Calculating PIP5K1B (1) ...
# INFO  @ Thu, 21 Dec 2023 07:45:43: Thread 3: total 5028 instances.
# INFO  @ Thu, 21 Dec 2023 07:45:43: Thread 1: Calculating controlguide578 (1) ...
# INFO  @ Thu, 21 Dec 2023 07:45:43: Thread 2: Calculating GALNT12 (1) ...
# INFO  @ Thu, 21 Dec 2023 07:45:43: Thread 3: Calculating MAP7 (1) ...
# INFO  @ Thu, 21 Dec 2023 07:45:48: Thread 3: Calculating WI2-2373I1.2 (1001) ...
# INFO  @ Thu, 21 Dec 2023 07:45:48: Thread 2: Calculating PASD1 (1001) ...
# INFO  @ Thu, 21 Dec 2023 07:45:48: Thread 0: Calculating TRIP11 (1001) ...
# INFO  @ Thu, 21 Dec 2023 07:45:48: Thread 1: Calculating EFHD1 (1001) ...
# INFO  @ Thu, 21 Dec 2023 07:45:52: Thread 3: Calculating HINT1 (2001) ...
# INFO  @ Thu, 21 Dec 2023 07:45:52: Thread 2: Calculating CLCF1 (2001) ...
# INFO  @ Thu, 21 Dec 2023 07:45:52: Thread 1: Calculating FAM133B (2001) ...
# INFO  @ Thu, 21 Dec 2023 07:45:52: Thread 0: Calculating TMEM181 (2001) ...
# INFO  @ Thu, 21 Dec 2023 07:45:57: Thread 3: Calculating ALOX12 (3001) ...
# INFO  @ Thu, 21 Dec 2023 07:45:57: Thread 2: Calculating TJP3 (3001) ...
# INFO  @ Thu, 21 Dec 2023 07:45:57: Thread 1: Calculating controlguide609 (3001) ...
# INFO  @ Thu, 21 Dec 2023 07:45:57: Thread 0: Calculating ADGRL2 (3001) ...
# INFO  @ Thu, 21 Dec 2023 07:46:02: Thread 3: Calculating CHRM5 (4001) ...
# INFO  @ Thu, 21 Dec 2023 07:46:02: Thread 2: Calculating EIF3M (4001) ...
# INFO  @ Thu, 21 Dec 2023 07:46:02: Thread 0: Calculating PZP (4001) ...
# INFO  @ Thu, 21 Dec 2023 07:46:06: Thread 1: Calculating DAZ2 (4001) ...
# INFO  @ Thu, 21 Dec 2023 07:46:07: Thread 3: Calculating NBPF15 (5001) ...
# INFO  @ Thu, 21 Dec 2023 07:46:07: Thread 0: Calculating TXN2 (5001) ...
# INFO  @ Thu, 21 Dec 2023 07:46:07: Thread 0 completed.
# INFO  @ Thu, 21 Dec 2023 07:46:08: Thread 2: Calculating PLK1 (5001) ...
# INFO  @ Thu, 21 Dec 2023 07:46:10: Thread 1: Calculating CCT7 (5001) ...
# INFO  @ Thu, 21 Dec 2023 07:46:10: Thread 1 completed.
# INFO  @ Thu, 21 Dec 2023 07:46:10: Thread 2 completed.
# INFO  @ Thu, 21 Dec 2023 07:46:10: Thread 3 completed.
# INFO  @ Thu, 21 Dec 2023 07:46:10: All threads completed.
# INFO  @ Thu, 21 Dec 2023 07:46:15: Permuting round 1 ...
# INFO  @ Thu, 21 Dec 2023 07:46:15: Thread 0 started.
# INFO  @ Thu, 21 Dec 2023 07:46:15: Thread 0: total 5028 instances.
# INFO  @ Thu, 21 Dec 2023 07:46:15: Thread 1 started.
# INFO  @ Thu, 21 Dec 2023 07:46:15: Thread 1: total 5028 instances.
# INFO  @ Thu, 21 Dec 2023 07:46:15: Thread 2 started.
# INFO  @ Thu, 21 Dec 2023 07:46:15: Thread 2: total 5028 instances.
# INFO  @ Thu, 21 Dec 2023 07:46:15: Thread 0: Calculating PIP5K1B (1) ...
# INFO  @ Thu, 21 Dec 2023 07:46:15: Thread 3 started.
# INFO  @ Thu, 21 Dec 2023 07:46:15: Thread 3: total 5028 instances.
# INFO  @ Thu, 21 Dec 2023 07:46:15: Thread 1: Calculating controlguide578 (1) ...
# INFO  @ Thu, 21 Dec 2023 07:46:15: Thread 2: Calculating GALNT12 (1) ...
# INFO  @ Thu, 21 Dec 2023 07:46:16: Thread 3: Calculating MAP7 (1) ...
# INFO  @ Thu, 21 Dec 2023 07:46:20: Thread 1: Calculating EFHD1 (1001) ...
# INFO  @ Thu, 21 Dec 2023 07:46:21: Thread 2: Calculating PASD1 (1001) ...
# INFO  @ Thu, 21 Dec 2023 07:46:21: Thread 3: Calculating WI2-2373I1.2 (1001) ...
# INFO  @ Thu, 21 Dec 2023 07:46:21: Thread 0: Calculating TRIP11 (1001) ...
# INFO  @ Thu, 21 Dec 2023 07:46:25: Thread 1: Calculating FAM133B (2001) ...
# INFO  @ Thu, 21 Dec 2023 07:46:25: Thread 3: Calculating HINT1 (2001) ...
# INFO  @ Thu, 21 Dec 2023 07:46:25: Thread 0: Calculating TMEM181 (2001) ...
# INFO  @ Thu, 21 Dec 2023 07:46:26: Thread 2: Calculating CLCF1 (2001) ...
# INFO  @ Thu, 21 Dec 2023 07:46:29: Thread 1: Calculating controlguide609 (3001) ...
# INFO  @ Thu, 21 Dec 2023 07:46:30: Thread 3: Calculating ALOX12 (3001) ...
# INFO  @ Thu, 21 Dec 2023 07:46:30: Thread 0: Calculating ADGRL2 (3001) ...
# INFO  @ Thu, 21 Dec 2023 07:46:31: Thread 2: Calculating TJP3 (3001) ...
# INFO  @ Thu, 21 Dec 2023 07:46:34: Thread 1: Calculating DAZ2 (4001) ...
# INFO  @ Thu, 21 Dec 2023 07:46:34: Thread 3: Calculating CHRM5 (4001) ...
# INFO  @ Thu, 21 Dec 2023 07:46:34: Thread 0: Calculating PZP (4001) ...
# INFO  @ Thu, 21 Dec 2023 07:46:36: Thread 2: Calculating EIF3M (4001) ...
# INFO  @ Thu, 21 Dec 2023 07:46:39: Thread 1: Calculating CCT7 (5001) ...
# INFO  @ Thu, 21 Dec 2023 07:46:39: Thread 3: Calculating NBPF15 (5001) ...
# INFO  @ Thu, 21 Dec 2023 07:46:39: Thread 0: Calculating TXN2 (5001) ...
# INFO  @ Thu, 21 Dec 2023 07:46:39: Thread 0 completed.
# INFO  @ Thu, 21 Dec 2023 07:46:39: Thread 1 completed.
# INFO  @ Thu, 21 Dec 2023 07:46:40: Thread 2: Calculating PLK1 (5001) ...
# INFO  @ Thu, 21 Dec 2023 07:46:40: Thread 2 completed.
# INFO  @ Thu, 21 Dec 2023 07:46:40: Thread 3 completed.
# INFO  @ Thu, 21 Dec 2023 07:46:40: All threads completed.
# INFO  @ Thu, 21 Dec 2023 07:46:45: Assigning p values...
# INFO  @ Thu, 21 Dec 2023 07:46:45: Permuting groups of gene with 4 sgRNAs per gene. Group progress: 3/4
# INFO  @ Thu, 21 Dec 2023 07:46:45: Start permuting 2 rounds ...
# INFO  @ Thu, 21 Dec 2023 07:46:46: Collecting 77441 sgRNAs from 20112 genes.
# INFO  @ Thu, 21 Dec 2023 07:46:47: Permuting round 0 ...
# INFO  @ Thu, 21 Dec 2023 07:46:47: Thread 0 started.
# INFO  @ Thu, 21 Dec 2023 07:46:47: Thread 0: total 5028 instances.
# INFO  @ Thu, 21 Dec 2023 07:46:47: Thread 1 started.
# INFO  @ Thu, 21 Dec 2023 07:46:47: Thread 1: total 5028 instances.
# INFO  @ Thu, 21 Dec 2023 07:46:47: Thread 2 started.
# INFO  @ Thu, 21 Dec 2023 07:46:47: Thread 2: total 5028 instances.
# INFO  @ Thu, 21 Dec 2023 07:46:47: Thread 0: Calculating PIP5K1B (1) ...
# INFO  @ Thu, 21 Dec 2023 07:46:47: Thread 3 started.
# INFO  @ Thu, 21 Dec 2023 07:46:47: Thread 3: total 5028 instances.
# INFO  @ Thu, 21 Dec 2023 07:46:47: Thread 1: Calculating controlguide578 (1) ...
# INFO  @ Thu, 21 Dec 2023 07:46:47: Thread 2: Calculating GALNT12 (1) ...
# INFO  @ Thu, 21 Dec 2023 07:46:47: Thread 3: Calculating MAP7 (1) ...
# INFO  @ Thu, 21 Dec 2023 07:46:52: Thread 0: Calculating TRIP11 (1001) ...
# INFO  @ Thu, 21 Dec 2023 07:46:52: Thread 1: Calculating EFHD1 (1001) ...
# INFO  @ Thu, 21 Dec 2023 07:46:52: Thread 2: Calculating PASD1 (1001) ...
# INFO  @ Thu, 21 Dec 2023 07:46:53: Thread 3: Calculating WI2-2373I1.2 (1001) ...
# INFO  @ Thu, 21 Dec 2023 07:46:57: Thread 1: Calculating FAM133B (2001) ...
# INFO  @ Thu, 21 Dec 2023 07:46:58: Thread 0: Calculating TMEM181 (2001) ...
# INFO  @ Thu, 21 Dec 2023 07:46:58: Thread 3: Calculating HINT1 (2001) ...
# INFO  @ Thu, 21 Dec 2023 07:46:58: Thread 2: Calculating CLCF1 (2001) ...
# INFO  @ Thu, 21 Dec 2023 07:47:02: Thread 1: Calculating controlguide609 (3001) ...
# INFO  @ Thu, 21 Dec 2023 07:47:02: Thread 0: Calculating ADGRL2 (3001) ...
# INFO  @ Thu, 21 Dec 2023 07:47:03: Thread 3: Calculating ALOX12 (3001) ...
# INFO  @ Thu, 21 Dec 2023 07:47:03: Thread 2: Calculating TJP3 (3001) ...
# INFO  @ Thu, 21 Dec 2023 07:47:07: Thread 0: Calculating PZP (4001) ...
# INFO  @ Thu, 21 Dec 2023 07:47:07: Thread 1: Calculating DAZ2 (4001) ...
# INFO  @ Thu, 21 Dec 2023 07:47:08: Thread 3: Calculating CHRM5 (4001) ...
# INFO  @ Thu, 21 Dec 2023 07:47:08: Thread 2: Calculating EIF3M (4001) ...
# INFO  @ Thu, 21 Dec 2023 07:47:12: Thread 0: Calculating TXN2 (5001) ...
# INFO  @ Thu, 21 Dec 2023 07:47:13: Thread 1: Calculating CCT7 (5001) ...
# INFO  @ Thu, 21 Dec 2023 07:47:13: Thread 0 completed.
# INFO  @ Thu, 21 Dec 2023 07:47:13: Thread 1 completed.
# INFO  @ Thu, 21 Dec 2023 07:47:13: Thread 2: Calculating PLK1 (5001) ...
# INFO  @ Thu, 21 Dec 2023 07:47:13: Thread 3: Calculating NBPF15 (5001) ...
# INFO  @ Thu, 21 Dec 2023 07:47:13: Thread 2 completed.
# INFO  @ Thu, 21 Dec 2023 07:47:13: Thread 3 completed.
# INFO  @ Thu, 21 Dec 2023 07:47:13: All threads completed.
# INFO  @ Thu, 21 Dec 2023 07:47:18: Permuting round 1 ...
# INFO  @ Thu, 21 Dec 2023 07:47:18: Thread 0 started.
# INFO  @ Thu, 21 Dec 2023 07:47:18: Thread 0: total 5028 instances.
# INFO  @ Thu, 21 Dec 2023 07:47:18: Thread 1 started.
# INFO  @ Thu, 21 Dec 2023 07:47:18: Thread 1: total 5028 instances.
# INFO  @ Thu, 21 Dec 2023 07:47:18: Thread 2 started.
# INFO  @ Thu, 21 Dec 2023 07:47:18: Thread 2: total 5028 instances.
# INFO  @ Thu, 21 Dec 2023 07:47:18: Thread 3 started.
# INFO  @ Thu, 21 Dec 2023 07:47:18: Thread 3: total 5028 instances.
# INFO  @ Thu, 21 Dec 2023 07:47:18: Thread 0: Calculating PIP5K1B (1) ...
# INFO  @ Thu, 21 Dec 2023 07:47:18: Thread 1: Calculating controlguide578 (1) ...
# INFO  @ Thu, 21 Dec 2023 07:47:18: Thread 2: Calculating GALNT12 (1) ...
# INFO  @ Thu, 21 Dec 2023 07:47:18: Thread 3: Calculating MAP7 (1) ...
# INFO  @ Thu, 21 Dec 2023 07:47:23: Thread 1: Calculating EFHD1 (1001) ...
# INFO  @ Thu, 21 Dec 2023 07:47:23: Thread 2: Calculating PASD1 (1001) ...
# INFO  @ Thu, 21 Dec 2023 07:47:23: Thread 3: Calculating WI2-2373I1.2 (1001) ...
# INFO  @ Thu, 21 Dec 2023 07:47:24: Thread 0: Calculating TRIP11 (1001) ...
# INFO  @ Thu, 21 Dec 2023 07:47:29: Thread 1: Calculating FAM133B (2001) ...
# INFO  @ Thu, 21 Dec 2023 07:47:29: Thread 2: Calculating CLCF1 (2001) ...
# INFO  @ Thu, 21 Dec 2023 07:47:29: Thread 3: Calculating HINT1 (2001) ...
# INFO  @ Thu, 21 Dec 2023 07:47:29: Thread 0: Calculating TMEM181 (2001) ...
# INFO  @ Thu, 21 Dec 2023 07:47:34: Thread 3: Calculating ALOX12 (3001) ...
# INFO  @ Thu, 21 Dec 2023 07:47:34: Thread 1: Calculating controlguide609 (3001) ...
# INFO  @ Thu, 21 Dec 2023 07:47:34: Thread 2: Calculating TJP3 (3001) ...
# INFO  @ Thu, 21 Dec 2023 07:47:34: Thread 0: Calculating ADGRL2 (3001) ...
# INFO  @ Thu, 21 Dec 2023 07:47:39: Thread 2: Calculating EIF3M (4001) ...
# INFO  @ Thu, 21 Dec 2023 07:47:39: Thread 1: Calculating DAZ2 (4001) ...
# INFO  @ Thu, 21 Dec 2023 07:47:39: Thread 0: Calculating PZP (4001) ...
# INFO  @ Thu, 21 Dec 2023 07:47:39: Thread 3: Calculating CHRM5 (4001) ...
# INFO  @ Thu, 21 Dec 2023 07:47:44: Thread 2: Calculating PLK1 (5001) ...
# INFO  @ Thu, 21 Dec 2023 07:47:44: Thread 0: Calculating TXN2 (5001) ...
# INFO  @ Thu, 21 Dec 2023 07:47:44: Thread 1: Calculating CCT7 (5001) ...
# INFO  @ Thu, 21 Dec 2023 07:47:44: Thread 0 completed.
# INFO  @ Thu, 21 Dec 2023 07:47:44: Thread 3: Calculating NBPF15 (5001) ...
# INFO  @ Thu, 21 Dec 2023 07:47:45: Thread 1 completed.
# INFO  @ Thu, 21 Dec 2023 07:47:45: Thread 2 completed.
# INFO  @ Thu, 21 Dec 2023 07:47:45: Thread 3 completed.
# INFO  @ Thu, 21 Dec 2023 07:47:45: All threads completed.
# INFO  @ Thu, 21 Dec 2023 07:47:49: Assigning p values...
# INFO  @ Thu, 21 Dec 2023 07:48:28: Permuting groups of gene with 8 sgRNAs per gene. Group progress: 4/4
# INFO  @ Thu, 21 Dec 2023 07:48:28: Start permuting 2 rounds ...
# INFO  @ Thu, 21 Dec 2023 07:48:29: Collecting 77441 sgRNAs from 20112 genes.
# INFO  @ Thu, 21 Dec 2023 07:48:30: Permuting round 0 ...
# INFO  @ Thu, 21 Dec 2023 07:48:31: Thread 0 started.
# INFO  @ Thu, 21 Dec 2023 07:48:31: Thread 0: total 5028 instances.
# INFO  @ Thu, 21 Dec 2023 07:48:31: Thread 1 started.
# INFO  @ Thu, 21 Dec 2023 07:48:31: Thread 1: total 5028 instances.
# INFO  @ Thu, 21 Dec 2023 07:48:31: Thread 2 started.
# INFO  @ Thu, 21 Dec 2023 07:48:31: Thread 2: total 5028 instances.
# INFO  @ Thu, 21 Dec 2023 07:48:31: Thread 0: Calculating PIP5K1B (1) ...
# INFO  @ Thu, 21 Dec 2023 07:48:31: Thread 3 started.
# INFO  @ Thu, 21 Dec 2023 07:48:31: Thread 3: total 5028 instances.
# INFO  @ Thu, 21 Dec 2023 07:48:31: Thread 1: Calculating controlguide578 (1) ...
# INFO  @ Thu, 21 Dec 2023 07:48:31: Thread 2: Calculating GALNT12 (1) ...
# INFO  @ Thu, 21 Dec 2023 07:48:31: Thread 3: Calculating MAP7 (1) ...
# INFO  @ Thu, 21 Dec 2023 07:48:37: Thread 2: Calculating PASD1 (1001) ...
# INFO  @ Thu, 21 Dec 2023 07:48:37: Thread 3: Calculating WI2-2373I1.2 (1001) ...
# INFO  @ Thu, 21 Dec 2023 07:48:37: Thread 0: Calculating TRIP11 (1001) ...
# INFO  @ Thu, 21 Dec 2023 07:48:37: Thread 1: Calculating EFHD1 (1001) ...
# INFO  @ Thu, 21 Dec 2023 07:48:43: Thread 0: Calculating TMEM181 (2001) ...
# INFO  @ Thu, 21 Dec 2023 07:48:43: Thread 1: Calculating FAM133B (2001) ...
# INFO  @ Thu, 21 Dec 2023 07:48:43: Thread 2: Calculating CLCF1 (2001) ...
# INFO  @ Thu, 21 Dec 2023 07:48:43: Thread 3: Calculating HINT1 (2001) ...
# INFO  @ Thu, 21 Dec 2023 07:48:48: Thread 0: Calculating ADGRL2 (3001) ...
# INFO  @ Thu, 21 Dec 2023 07:48:48: Thread 1: Calculating controlguide609 (3001) ...
# INFO  @ Thu, 21 Dec 2023 07:48:49: Thread 2: Calculating TJP3 (3001) ...
# INFO  @ Thu, 21 Dec 2023 07:48:49: Thread 3: Calculating ALOX12 (3001) ...
# INFO  @ Thu, 21 Dec 2023 07:48:54: Thread 0: Calculating PZP (4001) ...
# INFO  @ Thu, 21 Dec 2023 07:48:54: Thread 1: Calculating DAZ2 (4001) ...
# INFO  @ Thu, 21 Dec 2023 07:48:54: Thread 2: Calculating EIF3M (4001) ...
# INFO  @ Thu, 21 Dec 2023 07:48:55: Thread 3: Calculating CHRM5 (4001) ...
# INFO  @ Thu, 21 Dec 2023 07:49:00: Thread 0: Calculating TXN2 (5001) ...
# INFO  @ Thu, 21 Dec 2023 07:49:00: Thread 1: Calculating CCT7 (5001) ...
# INFO  @ Thu, 21 Dec 2023 07:49:00: Thread 0 completed.
# INFO  @ Thu, 21 Dec 2023 07:49:00: Thread 2: Calculating PLK1 (5001) ...
# INFO  @ Thu, 21 Dec 2023 07:49:00: Thread 1 completed.
# INFO  @ Thu, 21 Dec 2023 07:49:00: Thread 2 completed.
# INFO  @ Thu, 21 Dec 2023 07:49:00: Thread 3: Calculating NBPF15 (5001) ...
# INFO  @ Thu, 21 Dec 2023 07:49:01: Thread 3 completed.
# INFO  @ Thu, 21 Dec 2023 07:49:01: All threads completed.
# INFO  @ Thu, 21 Dec 2023 07:49:07: Permuting round 1 ...
# INFO  @ Thu, 21 Dec 2023 07:49:07: Thread 0 started.
# INFO  @ Thu, 21 Dec 2023 07:49:07: Thread 0: total 5028 instances.
# INFO  @ Thu, 21 Dec 2023 07:49:07: Thread 1 started.
# INFO  @ Thu, 21 Dec 2023 07:49:07: Thread 1: total 5028 instances.
# INFO  @ Thu, 21 Dec 2023 07:49:07: Thread 2 started.
# INFO  @ Thu, 21 Dec 2023 07:49:07: Thread 2: total 5028 instances.
# INFO  @ Thu, 21 Dec 2023 07:49:07: Thread 0: Calculating PIP5K1B (1) ...
# INFO  @ Thu, 21 Dec 2023 07:49:07: Thread 3 started.
# INFO  @ Thu, 21 Dec 2023 07:49:07: Thread 3: total 5028 instances.
# INFO  @ Thu, 21 Dec 2023 07:49:07: Thread 1: Calculating controlguide578 (1) ...
# INFO  @ Thu, 21 Dec 2023 07:49:07: Thread 2: Calculating GALNT12 (1) ...
# INFO  @ Thu, 21 Dec 2023 07:49:07: Thread 3: Calculating MAP7 (1) ...
# INFO  @ Thu, 21 Dec 2023 07:49:13: Thread 2: Calculating PASD1 (1001) ...
# INFO  @ Thu, 21 Dec 2023 07:49:13: Thread 1: Calculating EFHD1 (1001) ...
# INFO  @ Thu, 21 Dec 2023 07:49:13: Thread 0: Calculating TRIP11 (1001) ...
# INFO  @ Thu, 21 Dec 2023 07:49:14: Thread 3: Calculating WI2-2373I1.2 (1001) ...
# INFO  @ Thu, 21 Dec 2023 07:49:19: Thread 1: Calculating FAM133B (2001) ...
# INFO  @ Thu, 21 Dec 2023 07:49:19: Thread 2: Calculating CLCF1 (2001) ...
# INFO  @ Thu, 21 Dec 2023 07:49:19: Thread 0: Calculating TMEM181 (2001) ...
# INFO  @ Thu, 21 Dec 2023 07:49:19: Thread 3: Calculating HINT1 (2001) ...
# INFO  @ Thu, 21 Dec 2023 07:49:25: Thread 2: Calculating TJP3 (3001) ...
# INFO  @ Thu, 21 Dec 2023 07:49:25: Thread 1: Calculating controlguide609 (3001) ...
# INFO  @ Thu, 21 Dec 2023 07:49:25: Thread 0: Calculating ADGRL2 (3001) ...
# INFO  @ Thu, 21 Dec 2023 07:49:25: Thread 3: Calculating ALOX12 (3001) ...
# INFO  @ Thu, 21 Dec 2023 07:49:30: Thread 2: Calculating EIF3M (4001) ...
# INFO  @ Thu, 21 Dec 2023 07:49:30: Thread 0: Calculating PZP (4001) ...
# INFO  @ Thu, 21 Dec 2023 07:49:30: Thread 1: Calculating DAZ2 (4001) ...
# INFO  @ Thu, 21 Dec 2023 07:49:31: Thread 3: Calculating CHRM5 (4001) ...
# INFO  @ Thu, 21 Dec 2023 07:49:36: Thread 2: Calculating PLK1 (5001) ...
# INFO  @ Thu, 21 Dec 2023 07:49:36: Thread 1: Calculating CCT7 (5001) ...
# INFO  @ Thu, 21 Dec 2023 07:49:36: Thread 0: Calculating TXN2 (5001) ...
# INFO  @ Thu, 21 Dec 2023 07:49:37: Thread 0 completed.
# INFO  @ Thu, 21 Dec 2023 07:49:37: Thread 1 completed.
# INFO  @ Thu, 21 Dec 2023 07:49:37: Thread 2 completed.
# INFO  @ Thu, 21 Dec 2023 07:49:37: Thread 3: Calculating NBPF15 (5001) ...
# INFO  @ Thu, 21 Dec 2023 07:49:37: Thread 3 completed.
# INFO  @ Thu, 21 Dec 2023 07:49:37: All threads completed.
# INFO  @ Thu, 21 Dec 2023 07:49:43: Assigning p values...
# INFO  @ Thu, 21 Dec 2023 07:49:45: Writing gene results to output_mle.gene_summary.txt
# INFO  @ Thu, 21 Dec 2023 07:49:45: Writing sgRNA results to output_mle.sgrna_summary.txt

# %%
sgRNA_summary_mle = pd.read_table('mle/output_mle.sgrna_summary.txt')
sgRNA_summary_mle.shape
# Out:
# (77441, 3)

# %%
sgRNA_summary_mle.head(10)
# Out:
#         Gene     sgRNA  eff
# 0     DUSP14  ID_30030    1
# 1     DUSP14  ID_30029    1
# 2     DUSP14  ID_30028    1
# 3     DUSP14  ID_30027    1
# 4  HIST1H2BL  ID_21657    1
# 5  HIST1H2BL  ID_21660    1
# 6  HIST1H2BL  ID_21658    1
# 7  HIST1H2BL  ID_21659    1
# 8     CTAGE6  ID_69143    1
# 9     CTAGE6  ID_69142    1

# %%
gene_summary_mle = pd.read_table('mle/output_mle.gene_summary.txt')
gene_summary_mle.shape
# Out:
# (20112, 14)

# %%
gene_summary_mle.head(10)
# Out:
#               Gene  sgRNA  Vehicle|beta  Vehicle|z  Vehicle|p-value  \
# 0           DUSP14      4     -0.046593  -0.406180          0.81056
# 1        HIST1H2BL      4     -0.387780  -1.370100          0.09825
# 2           CTAGE6      4      0.070307   0.389960          0.70744
# 3         TBC1D10C      4     -0.004010  -0.053744          0.98086
# 4          PIP5K1B      4      0.190520   1.373800          0.29410
# 5  controlguide578      1      0.415150   0.391540          0.22817
# 6          GALNT12      4      0.111720   0.582340          0.54196
# 7             MAP7      4      0.246180   1.049700          0.17363
# 8            APBB3      4     -0.043763  -0.338840          0.82244
# 9             EXD2      4      0.151600   0.782790          0.40528
#
#    Vehicle|fdr  Vehicle|wald-p-value  Vehicle|wald-fdr  APR|beta    APR|z  \
# 0      0.99079               0.68461           0.96053  0.071544  0.62381
# 1      0.64533               0.17065           0.95209 -0.066854 -0.23705
# 2      0.98061               0.69656           0.96074 -0.107730 -0.59718
# 3      0.99824               0.95714           0.99509 -0.045206 -0.60519
# 4      0.87983               0.16950           0.95209  0.179410  1.29340
# 5      0.83798               0.69540           0.96074  0.662850  0.62516
# 6      0.95750               0.56034           0.95300  0.212830  1.10950
# 7      0.78962               0.29388           0.95209  0.342050  1.45860
# 8      0.99079               0.73473           0.96644 -0.106320 -0.82249
# 9      0.92816               0.43375           0.95209  0.225530  1.16470
#
#    APR|p-value  APR|fdr  APR|wald-p-value  APR|wald-fdr
# 0      0.78187  0.98870           0.53275       0.84452
# 1      0.73523  0.98462           0.81262       0.94193
# 2      0.60800  0.97167           0.55039       0.85088
# 3      0.80842  0.99177           0.54505       0.84882
# 4      0.43541  0.93838           0.19587       0.75718
# 5      0.11182  0.67497           0.53187       0.84402
# 6      0.34596  0.90939           0.26723       0.76828
# 7      0.12197  0.68885           0.14468       0.75718
# 8      0.61088  0.97209           0.41080       0.81037
# 9      0.31678  0.89732           0.24414       0.76466

# %%
gene_summary_mle.columns
# Out:
# Index(['Gene', 'sgRNA', 'Vehicle|beta', 'Vehicle|z', 'Vehicle|p-value',
#        'Vehicle|fdr', 'Vehicle|wald-p-value', 'Vehicle|wald-fdr', 'APR|beta',
#        'APR|z', 'APR|p-value', 'APR|fdr', 'APR|wald-p-value', 'APR|wald-fdr'],
#       dtype='object')

# %%
gene_summary_mle_info = {'Column_name': gene_summary_mle.columns, 
                     'Content': ['Gene ID', 
                                 'The number of targeting sgRNAs for each gene', 
                                 'The beta score of this gene in Vehicle condition', 
                                 'The raw p-value (using permutation) of this gene in Vehicle condition',
                                 'The false discovery rate for this gene in Vehicle selection', 
                                 'The z-score associated with Wald test in Vehicle selection',
                                 'The p-value using Wald test in the Vehicle selection',
                                 'The false discovery rate of the Wald test in the Vehicle selection',
                                 'The beta score of this gene in APR condition', 
                                 'The raw p-value (using permutation) of this gene in APR condition',
                                 'The false discovery rate for this gene in APR selection', 
                                 'The z-score associated with Wald test in APR selection',
                                 'The p-value using Wald test in the APR selection',
                                 'The false discovery rate of the Wald test in the APR selection'
                                 ]}
pd.DataFrame.from_dict(gene_summary_mle_info)
# Out:
#              Column_name                                            Content
# 0                   Gene                                            Gene ID
# 1                  sgRNA       The number of targeting sgRNAs for each gene
# 2           Vehicle|beta   The beta score of this gene in Vehicle condition
# 3              Vehicle|z  The raw p-value (using permutation) of this ge...
# 4        Vehicle|p-value  The false discovery rate for this gene in Vehi...
# 5            Vehicle|fdr  The z-score associated with Wald test in Vehic...
# 6   Vehicle|wald-p-value  The p-value using Wald test in the Vehicle sel...
# 7       Vehicle|wald-fdr  The false discovery rate of the Wald test in t...
# 8               APR|beta       The beta score of this gene in APR condition
# 9                  APR|z  The raw p-value (using permutation) of this ge...
# 10           APR|p-value  The false discovery rate for this gene in APR ...
# 11               APR|fdr  The z-score associated with Wald test in APR s...
# 12      APR|wald-p-value   The p-value using Wald test in the APR selection
# 13          APR|wald-fdr  The false discovery rate of the Wald test in t...

# %% [markdown]
# #### Visualize mle results
#
# Create volcano plot from mle gene summary to visualize the result for APT vs T0 using `Gene` column for label option, `APR|beta` for log fold change, `APR|wald-p-value` for p-value, and `APR|wald-fdr` for fdr option.

# %%
! Rscript scripts/volcanoplot.rscript --input mle/output_mle.gene_summary.txt \
--fdr_col 14 --pval_col 13 --lfc_col 9 --label_col 1 --signif_thresh 0.05 --lfc_thresh 0.0 --topn 10
# Out:
# null device
#           1
# [1] "Create volcano_plot.pdf....... DONE."

# %% [markdown]
# [MAGeCK mle APT vs T0 volcano plot](./mle/volcano_plot_APR-T0.pdf)

# %%
from IPython.display import IFrame
IFrame("mle/volcano_plot_APR-T0.pdf", width=600, height=300)
# Out:
#         <iframe
#             width="600"
#             height="300"
#             src="mle/volcano_plot_APR-T0.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# Create volcano plot from mle gene summary to visualize the result for Vehicle vs T0 using `Gene` column for label option, `Vehicle|beta` for log fold change, `Vehicle|wald-p-value` for p-value, and `Vehicle|wald-fdr` for fdr option.

# %%
! Rscript scripts/volcanoplot.rscript --input mle/output_mle.gene_summary.txt \
--fdr_col 8 --pval_col 7 --lfc_col 3 --label_col 1 --signif_thresh 0.05 --lfc_thresh 0.0 --topn 10
# Out:
# null device
#           1
# [1] "Create volcano_plot.pdf....... DONE."

# %% [markdown]
# [MAGeCK mle Vehicle vs T0 volcano plot](./mle/volcano_plot_Vehicle-T0.pdf)

# %%
from IPython.display import IFrame
IFrame("mle/volcano_plot_Vehicle-T0.pdf", width=600, height=300)
# Out:
#         <iframe
#             width="600"
#             height="300"
#             src="mle/volcano_plot_Vehicle-T0.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
